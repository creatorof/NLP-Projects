# %%
import nltk
from nltk.corpus import brown
nltk.download('brown')
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\Sagar\AppData\Roaming\nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# True

# %%
import torch
import numpy as np
import torch.nn as nn
import torch.optim as optim 
import matplotlib.pyplot as plt

# %%
brown.sents()
# Out:
# [['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', 'Friday', 'an', 'investigation', 'of', "Atlanta's", 'recent', 'primary', 'election', 'produced', '``', 'no', 'evidence', "''", 'that', 'any', 'irregularities', 'took', 'place', '.'], ['The', 'jury', 'further', 'said', 'in', 'term-end', 'presentments', 'that', 'the', 'City', 'Executive', 'Committee', ',', 'which', 'had', 'over-all', 'charge', 'of', 'the', 'election', ',', '``', 'deserves', 'the', 'praise', 'and', 'thanks', 'of', 'the', 'City', 'of', 'Atlanta', "''", 'for', 'the', 'manner', 'in', 'which', 'the', 'election', 'was', 'conducted', '.'], ...]

# %% [markdown]
# ## 1. Tokenize

# %%
corpus_tokenized = brown.sents()[:3000]

# %% [markdown]
# ## 2. Numericalize

# %% [markdown]
# ### 2.1 Get all the uniques words

# %%
flatten = lambda l: [item for sublist in l for item in sublist]
vocabs  = list(set(flatten(corpus_tokenized)))

# %%
vocabs
# Out:
# ['hooked',
#  'jewels',
#  'Affairs',
#  'chef',
#  'crosswalk',
#  'controversial',
#  'Troop',
#  'amicable',
#  'F',
#  'Johnson',
#  'segregated',
#  'eliminating',
#  '300',
#  'diem',
#  'believed',
#  'Military',
#  '300-450',
#  'Blumberg',
#  'doubted',
#  'industries',
#  'created',
#  'death',
#  'beliefs',
#  '963',
#  'none',
#  'attracted',
#  'price',
#  '205-pound',
#  'governing',
#  'notarized',
#  'US',
#  'secret',
#  'hire',
#  'ran',
#  'items',
#  'cannot',
#  'checks',
#  'dentistry',
#  'Gentile',
#  'ultimate',
#  'Mustang',
#  'increase',
#  'calmest',
#  'performing',
#  'Elks',
#  'team',
#  'coup',
#  'Duren',
#  'long-time',
#  'sentencing',
#  'Spahn',
#  'Home',
#  'protested',
#  "Stein's",
#  'fullbacking',
#  'newspapers',
#  'rapped',
#  '4-year-old',
#  'purse',
#  "Canada's",
#  'Turandot',
#  'Webster',
#  'allies',
#  'fiance',
#  'computed',
#  'Split',
#  'precedent',
#  'Snellville',
#  'Canadian',
#  'mentioned',
#  'Time',
#  'youngest',
#  'Examiner',
#  'drafted',
#  'Foundation',
#  '$109',
#  'fence',
#  'reportedly',
#  '$200,000',
#  'scrimmaged',
#  'North',
#  'aggravates',
#  'jointly',
#  'taken',
#  'every',
#  'Hubbell',
#  'apprentice',
#  'receives',
#  'revealed',
#  'penalized',
#  'Terral',
#  'Nov.',
#  'availability',
#  'Griffin',
#  'Dussa',
#  'Pelham',
#  'leaders',
#  'god-like',
#  'teach',
#  'Friends',
#  'Herbert',
#  'direction',
#  'Jordan',
#  'comfort',
#  'hired',
#  'Whipple',
#  'Bermuda',
#  'deterrent',
#  'love',
#  'chose',
#  'development',
#  '15-year-old',
#  'AF',
#  'Portugal',
#  'properties',
#  'scholastically',
#  'rain',
#  'republic',
#  'nuclear',
#  'Lisle',
#  'favored',
#  'dedicated',
#  'Voters',
#  'collections',
#  'alternate',
#  'Inheriting',
#  'Sheeran',
#  'church-state',
#  'warmed',
#  'View',
#  'eminent',
#  'sales',
#  'Raymondville',
#  'waved',
#  'steep',
#  'lace',
#  'Winchell',
#  'Kelsey',
#  'Cooperation',
#  'burrowed',
#  'indecisive',
#  'stand',
#  'trucks',
#  'lawmakers',
#  'Delinquency',
#  'sports',
#  'Sunay',
#  'ability',
#  'Five',
#  'adverse',
#  'swim',
#  'Country',
#  'May',
#  'physically',
#  'gliders',
#  'Barnett',
#  'Fred',
#  '$15,000,000',
#  'taxes',
#  'Pantas',
#  'dots',
#  'reiterating',
#  'connect',
#  'gained',
#  'Rickenbaugh',
#  'dean',
#  'awareness',
#  'hotel',
#  'hazards',
#  'Cooperman',
#  'realize',
#  'children',
#  'Rayburn',
#  'arrest',
#  'billion',
#  'blocked',
#  'presumed',
#  'offenses',
#  '1,700',
#  'special-interest',
#  'generous',
#  'Isodine',
#  'bateau',
#  "Party's",
#  'Associated',
#  'trial',
#  'Wabash',
#  'loyalty',
#  "ruling's",
#  'ten',
#  '1-0',
#  'find',
#  'intensifying',
#  'reserves',
#  'drain',
#  'Standard',
#  'athletic',
#  'relearns',
#  'Viet',
#  'surprise',
#  'Ernie',
#  'jazz',
#  'cab',
#  'script',
#  'cracked',
#  '5-run',
#  'Newburger',
#  'Riders',
#  'Frank',
#  'Proceeds',
#  'printed',
#  'delegations',
#  'streaked',
#  'docile',
#  '1:48',
#  "Kunkel's",
#  '13',
#  "today's",
#  'limited',
#  'write',
#  "children's",
#  'error',
#  'loading',
#  'Siberia',
#  'uptrend',
#  'tasteful',
#  'incumbent',
#  'surprised',
#  'rightfield',
#  'English',
#  'developments',
#  'Burgess',
#  'Finalists',
#  'Greenwich',
#  'Toying',
#  'claimed',
#  'all-county',
#  'Alfred',
#  'Conference',
#  'denied',
#  'five-day',
#  'conditions',
#  'pay',
#  'British',
#  'sing',
#  'cross-examination',
#  'stephanotis',
#  'deed',
#  'Son',
#  'code',
#  'deductible',
#  'Travelers',
#  'against',
#  'Maureen',
#  'intensified',
#  'tracing',
#  'Sharon',
#  '60',
#  'geometrically',
#  'kids',
#  'funeral',
#  'Marc',
#  're-elected',
#  'odds',
#  'nonviolent',
#  'proved',
#  'sees',
#  "Meyner's",
#  'Mercer',
#  'T.',
#  '2825',
#  'intern',
#  'target',
#  'smell',
#  'couple',
#  'powerful',
#  'indictments',
#  'famous',
#  'integration',
#  'James',
#  'franchise',
#  'piping',
#  'Simpson',
#  'Coulson',
#  'Desmond',
#  'Robinsonville',
#  'repairs',
#  'interesting',
#  'Stock',
#  '37',
#  'rest',
#  'A.A.U.',
#  'prospects',
#  'urgency',
#  'barely',
#  'Harvest',
#  '56',
#  'factory',
#  "Blanchard's",
#  'implements',
#  'inscription',
#  "secretary's",
#  'Providence',
#  'Brandeis',
#  'delayed',
#  'sidled',
#  'happened',
#  'Bldg.',
#  'Should',
#  'discriminatory',
#  'underwriting',
#  'agents',
#  'Hyannis',
#  'Profili',
#  'viewpoint',
#  'heroin',
#  'away',
#  'Crump',
#  'universities',
#  "Rayburn's",
#  'receipts',
#  'movements',
#  'wore',
#  'reputedly',
#  'win',
#  'Rider',
#  'four',
#  'sons',
#  'Breuer',
#  'finishing',
#  'Sapio',
#  'completion',
#  'body',
#  'Rev.',
#  'slowly-mending',
#  'own',
#  '10',
#  'privileged',
#  '65',
#  'deserts',
#  'miss',
#  'enunciate',
#  'boast',
#  'flower',
#  'imply',
#  'reason',
#  'discharging',
#  'deduction',
#  'named',
#  'Norway',
#  'Club',
#  'to',
#  'SWC',
#  'reporters',
#  'canceled',
#  'Mrs',
#  'and',
#  'reiterated',
#  'National',
#  'Newsom',
#  'status',
#  '$5000',
#  'declares',
#  'shoes',
#  'Shriver',
#  'Wallace',
#  'follows',
#  'entering',
#  'title',
#  'Giorgio',
#  'receive',
#  'creating',
#  'top-ranking',
#  'duffer',
#  'someplace',
#  'whether',
#  'annual',
#  'indicating',
#  'unit',
#  'front',
#  'types',
#  'newsman',
#  'tension',
#  'Smithfield',
#  'modified',
#  'undersea',
#  'Patrolmen',
#  'intimidation',
#  "Nobody's",
#  'Saga',
#  'Chapter',
#  "teams'",
#  'minister',
#  'Hole',
#  'persecution',
#  'physics',
#  'Winston',
#  '60,000',
#  'proceeds',
#  'Dilworth',
#  'Terry',
#  'above',
#  '1600',
#  'Spring',
#  '100%',
#  'preoccupied',
#  'difficult',
#  'Mayoral',
#  'chairmen',
#  'so-called',
#  'carved',
#  '31',
#  "farmers'",
#  'candidates',
#  'wrongdoing',
#  'whereby',
#  '10%',
#  'twelfth',
#  'gift',
#  'doubt',
#  'very',
#  '1920s',
#  'Metal',
#  'cotton',
#  'Philadelphia',
#  'frock',
#  'meaningless',
#  'published',
#  'Pinar',
#  'production',
#  'recommendations',
#  'Claude',
#  'driveway',
#  'rescind',
#  'Jimmie',
#  '3-hitter',
#  'smashed',
#  'horse',
#  'sources',
#  'naturally',
#  'Bronx',
#  "Controller's",
#  'grass-green',
#  'Germania',
#  'slice',
#  'conspirators',
#  'middle',
#  'TNT',
#  'architecture',
#  'choosing',
#  'Kamens',
#  'signs',
#  'prominently',
#  'bombs',
#  'Mercury',
#  '10,000,000',
#  'Attilio',
#  'generation',
#  '$451,500',
#  'Gehrig',
#  'stood',
#  'fourth',
#  'war',
#  'Net',
#  'Ferdinand',
#  'Dobbs',
#  'Diversified',
#  'governor',
#  "conference's",
#  '$10,000',
#  "Tribe's",
#  'mad',
#  'quarters',
#  'jury',
#  'Commissioner',
#  'big',
#  'robbery',
#  'Los',
#  'Md.',
#  'hoc',
#  'perform',
#  'Outstanding',
#  'episode',
#  "else's",
#  'nationwide',
#  'succeeds',
#  'Cotten',
#  'views',
#  'far-flung',
#  'basically',
#  'professional',
#  '354',
#  'Hackett',
#  'Spice-Nice',
#  'well-established',
#  'pays',
#  'presides',
#  'motorist',
#  'Nevada',
#  'showings',
#  '17',
#  'Estimates',
#  'division',
#  'Gordin',
#  'Survivors',
#  'operated',
#  'shall',
#  'head-on',
#  "Stengel's",
#  'Stevens',
#  '80',
#  "That's",
#  'sound',
#  'evening',
#  'Pittsburgh',
#  'regularly',
#  'Tommy',
#  'adapting',
#  'Buddy',
#  'Smoky',
#  'Bowden',
#  'rescued',
#  'apparent',
#  'propelling',
#  'switching',
#  'repeatedly',
#  '$115,000',
#  'sought',
#  'Olvey',
#  'work',
#  'Hess',
#  'sit',
#  'popular',
#  'employ',
#  'predicted',
#  'predict',
#  'coordinate',
#  'ye',
#  '96',
#  'Del',
#  'Palm',
#  'inflicted',
#  'Longhorn',
#  'Due',
#  'ruefully',
#  'camping-out',
#  "I'll",
#  'Army',
#  'pensions',
#  'manufacturers',
#  'Gods',
#  'appearing',
#  'Taxation',
#  'retrenching',
#  'Serra',
#  'third',
#  'driving',
#  'credits',
#  'bestowed',
#  'Agencies',
#  'expansive',
#  'Christine',
#  'assailant',
#  'wavelengths',
#  'Butlers',
#  'watched',
#  'Treatment',
#  'dilemma',
#  '26-year-old',
#  'purposes',
#  'whipped',
#  'holders',
#  'Angel',
#  'Merger',
#  'conciliatory',
#  'done',
#  'tossed',
#  '23d',
#  'gather',
#  'Seekonk',
#  'notion',
#  '28',
#  'jotted',
#  'weight',
#  'comparable',
#  'Nolan',
#  'Kenilworth',
#  'floor',
#  'reactors',
#  'Dresbachs',
#  'rumored',
#  '30',
#  'Boyer',
#  'different',
#  'exciting',
#  'Aurora',
#  'swimming',
#  'Opposition',
#  'split-level',
#  'Cocktail',
#  'early',
#  'obstacle',
#  'conscious',
#  'trust',
#  'Lawrence',
#  'announcing',
#  'adviser',
#  'salary',
#  'Anson',
#  'marriage',
#  'their',
#  'clothes',
#  'compete',
#  'split',
#  'forever',
#  'Floresville',
#  'Abbey',
#  'fiscal',
#  'arms',
#  "'55",
#  'Change',
#  'outspoken',
#  'thinks',
#  'wagging',
#  'Douglas',
#  'appearance',
#  'Sciences',
#  'ballots',
#  'Kiefferm',
#  'invites',
#  'Letters',
#  'hand',
#  'democracy',
#  'asserted',
#  'onto',
#  'Holy',
#  'ex-singer',
#  'Sheraton-Dallas',
#  'dessert',
#  'winless',
#  'dark',
#  'quarter-mile',
#  'clashes',
#  'Morris',
#  'born',
#  'carrying',
#  'Kathleen',
#  'scientific',
#  'Huddle',
#  'called',
#  'masses',
#  'Bursts',
#  'foes',
#  'chemicals',
#  'Harrity',
#  'transportation',
#  'freshman',
#  'Clipper',
#  'Economic',
#  'weapons',
#  'termination',
#  'constituted',
#  'International',
#  'Mets',
#  'teaching',
#  'players',
#  'coming',
#  'Planning',
#  'effort',
#  'suicide',
#  'Usually',
#  '273',
#  'Hampton',
#  'daylight',
#  "we've",
#  'copy',
#  'severely',
#  'satisfaction',
#  'Ehlers',
#  'turned',
#  'education',
#  'warhead',
#  'contractors',
#  '1925',
#  'eve',
#  'Asilomar',
#  'consisted',
#  'urban',
#  '520-acre',
#  'Local',
#  'tests',
#  '$2,330,000',
#  'still',
#  'appoint',
#  'assumed',
#  'A',
#  'Kochaneks',
#  '``',
#  'exploratory',
#  'abroad',
#  '8,293',
#  'Allegretti',
#  'Section',
#  'Senese',
#  'peace',
#  'mainly',
#  'standard',
#  'Samuel',
#  'Legislature',
#  'verify',
#  '$50',
#  'prepayment',
#  'Prince',
#  'whisking',
#  'assertion',
#  'absolute',
#  'camps',
#  'damage',
#  'Twenty-one-year-old',
#  '$120',
#  'Report',
#  'Bradford',
#  'Rowley',
#  '$400',
#  'pounds',
#  'seventh',
#  'percentages',
#  'rings',
#  'wooden',
#  'Basin',
#  'tax',
#  'six-point',
#  'statements',
#  'Much',
#  'Major',
#  'pertained',
#  'ministerial',
#  'spot',
#  'Clerks',
#  'Millie',
#  'Foods',
#  'eyebrow',
#  'Ditmar',
#  'she',
#  'princesse',
#  'Grooms',
#  'research',
#  'firmer',
#  'Emcee',
#  'make',
#  'Last',
#  'intercepted',
#  "moment's",
#  'golfer',
#  'Rylie',
#  'Schley',
#  'Petitions',
#  'rush',
#  'bunter',
#  'Savannah',
#  'private',
#  'Arrington',
#  'slogan',
#  'Reama',
#  'seems',
#  'Jane',
#  'offenders',
#  'businesses',
#  'Cheshire',
#  'ex-Mrs.',
#  'weighs',
#  'responsible',
#  'Before',
#  'Seattle',
#  'nose',
#  'guiding',
#  'identically',
#  'equally',
#  'organdy',
#  'schedules',
#  'sculpture',
#  'Eaton',
#  'announced',
#  'pre-Easter',
#  'onslaught',
#  'Utah',
#  'segregation',
#  '8:30',
#  'Bad',
#  '10-team',
#  'forbids',
#  '1971',
#  'members',
#  'manslaughter',
#  'conferees',
#  'fashions',
#  'irregularities',
#  'Distributive',
#  'Beach',
#  'Raesz',
#  '$14',
#  'taxing',
#  'championships',
#  "Hughes'",
#  'unmeritorious',
#  'its',
#  'daily',
#  'mile',
#  'August',
#  'creditable',
#  'I',
#  '3-0',
#  'overnight',
#  'janitors',
#  'those',
#  'immediate',
#  'Hemus',
#  'achieved',
#  'decoration',
#  "League's",
#  'screen',
#  'Manor',
#  'arrests',
#  'heritage',
#  'register',
#  'NYU',
#  'cautioned',
#  'stupidity',
#  'president',
#  'Inspections',
#  'returning',
#  'determining',
#  'German',
#  'Maple',
#  '6-5',
#  "Mills's",
#  'promising',
#  'settlement',
#  'certainly',
#  'Super',
#  '5847',
#  'Banks',
#  'Lane',
#  'pier',
#  'House',
#  'successful',
#  'gals',
#  'fields',
#  'blond',
#  'people',
#  'Faced',
#  'teams',
#  'Liberal',
#  'End',
#  'Hal',
#  'Pye',
#  'eighth',
#  'operators',
#  'controlled',
#  'Writers',
#  'defendant',
#  'Narragansett',
#  'proper',
#  'voice',
#  "Thursday's",
#  'Motorists',
#  "Case's",
#  'acting',
#  'year',
#  'carries',
#  'pitching',
#  'here',
#  'characterized',
#  'based',
#  'They',
#  'Louise',
#  'fewer',
#  'SW',
#  'subpenas',
#  'Graduate',
#  'masquerade',
#  'Jail',
#  'all-woman',
#  'breaking',
#  'terms',
#  'yearly',
#  'hood',
#  'Steeves',
#  'pride',
#  'Dumas',
#  'Ainsley',
#  'career',
#  'banquet',
#  'affair',
#  'behind',
#  'expenses',
#  'orderly',
#  'value',
#  'mutter',
#  'Innumerable',
#  'learn',
#  'gas',
#  'application',
#  'Camille',
#  'ayes',
#  'Oilers',
#  'carry',
#  'showman',
#  'airfield',
#  'Dr.',
#  'internal',
#  'senior',
#  '46',
#  '823',
#  'Madison',
#  'lover',
#  'ordinary',
#  'results',
#  'elephants',
#  'king',
#  'anti-submarine',
#  'tragedy',
#  'chip',
#  'communism',
#  '1935',
#  'Meet',
#  'Munger',
#  'laurels',
#  'showmanship',
#  'affect',
#  'left',
#  'preserve',
#  'delegates',
#  'codes',
#  '51',
#  'Reeder',
#  'Anna',
#  'Jimmy',
#  'run-up',
#  'Bassi',
#  '9-7',
#  "club's",
#  'behavior',
#  'youthful',
#  'overwhelmingly',
#  'bayonet',
#  'provisional',
#  'attack',
#  'conspiracy',
#  'polled',
#  'colleges',
#  'Carnival',
#  'Symphony',
#  'asking',
#  'netted',
#  'figuring',
#  'Black',
#  'admission',
#  'caskets',
#  'keyhole',
#  'Walsh',
#  'Flock',
#  'Parichy',
#  "House's",
#  'robbed',
#  'bowl',
#  'Republican-controlled',
#  'experimental',
#  'saws',
#  'Legion',
#  'water',
#  'writer',
#  'parent',
#  'Moving',
#  'aged-care',
#  'pl.',
#  'Kas.',
#  'Tom',
#  'quarterly',
#  'obligation',
#  'Anniston',
#  'family',
#  'Detroit',
#  'solution',
#  'Cedar',
#  'Rex',
#  'Tractor',
#  'enjoy',
#  'services',
#  'adjournment',
#  'fund-raiser',
#  'Tim',
#  'supporters',
#  'P.M.',
#  'acquittal',
#  'Olivia',
#  'donated',
#  'Lay',
#  '13-8',
#  'lagged',
#  ...]

# %% [markdown]
# ### 2.2 Add `<UNK>` at index 0

# %%
vocabs.insert(0,'<UNK>')

# %% [markdown]
# ### 2.3 Create word2index dictionary

# %%
word2index = {v: idx for idx, v in enumerate(vocabs)}

# %%
word2index
# Out:
# {'<UNK>': 0,
#  'hooked': 1,
#  'jewels': 2,
#  'Affairs': 3,
#  'chef': 4,
#  'crosswalk': 5,
#  'controversial': 6,
#  'Troop': 7,
#  'amicable': 8,
#  'F': 9,
#  'Johnson': 10,
#  'segregated': 11,
#  'eliminating': 12,
#  '300': 13,
#  'diem': 14,
#  'believed': 15,
#  'Military': 16,
#  '300-450': 17,
#  'Blumberg': 18,
#  'doubted': 19,
#  'industries': 20,
#  'created': 21,
#  'death': 22,
#  'beliefs': 23,
#  '963': 24,
#  'none': 25,
#  'attracted': 26,
#  'price': 27,
#  '205-pound': 28,
#  'governing': 29,
#  'notarized': 30,
#  'US': 31,
#  'secret': 32,
#  'hire': 33,
#  'ran': 34,
#  'items': 35,
#  'cannot': 36,
#  'checks': 37,
#  'dentistry': 38,
#  'Gentile': 39,
#  'ultimate': 40,
#  'Mustang': 41,
#  'increase': 42,
#  'calmest': 43,
#  'performing': 44,
#  'Elks': 45,
#  'team': 46,
#  'coup': 47,
#  'Duren': 48,
#  'long-time': 49,
#  'sentencing': 50,
#  'Spahn': 51,
#  'Home': 52,
#  'protested': 53,
#  "Stein's": 54,
#  'fullbacking': 55,
#  'newspapers': 56,
#  'rapped': 57,
#  '4-year-old': 58,
#  'purse': 59,
#  "Canada's": 60,
#  'Turandot': 61,
#  'Webster': 62,
#  'allies': 63,
#  'fiance': 64,
#  'computed': 65,
#  'Split': 66,
#  'precedent': 67,
#  'Snellville': 68,
#  'Canadian': 69,
#  'mentioned': 70,
#  'Time': 71,
#  'youngest': 72,
#  'Examiner': 73,
#  'drafted': 74,
#  'Foundation': 75,
#  '$109': 76,
#  'fence': 77,
#  'reportedly': 78,
#  '$200,000': 79,
#  'scrimmaged': 80,
#  'North': 81,
#  'aggravates': 82,
#  'jointly': 83,
#  'taken': 84,
#  'every': 85,
#  'Hubbell': 86,
#  'apprentice': 87,
#  'receives': 88,
#  'revealed': 89,
#  'penalized': 90,
#  'Terral': 91,
#  'Nov.': 92,
#  'availability': 93,
#  'Griffin': 94,
#  'Dussa': 95,
#  'Pelham': 96,
#  'leaders': 97,
#  'god-like': 98,
#  'teach': 99,
#  'Friends': 100,
#  'Herbert': 101,
#  'direction': 102,
#  'Jordan': 103,
#  'comfort': 104,
#  'hired': 105,
#  'Whipple': 106,
#  'Bermuda': 107,
#  'deterrent': 108,
#  'love': 109,
#  'chose': 110,
#  'development': 111,
#  '15-year-old': 112,
#  'AF': 113,
#  'Portugal': 114,
#  'properties': 115,
#  'scholastically': 116,
#  'rain': 117,
#  'republic': 118,
#  'nuclear': 119,
#  'Lisle': 120,
#  'favored': 121,
#  'dedicated': 122,
#  'Voters': 123,
#  'collections': 124,
#  'alternate': 125,
#  'Inheriting': 126,
#  'Sheeran': 127,
#  'church-state': 128,
#  'warmed': 129,
#  'View': 130,
#  'eminent': 131,
#  'sales': 132,
#  'Raymondville': 133,
#  'waved': 134,
#  'steep': 135,
#  'lace': 136,
#  'Winchell': 137,
#  'Kelsey': 138,
#  'Cooperation': 139,
#  'burrowed': 140,
#  'indecisive': 141,
#  'stand': 142,
#  'trucks': 143,
#  'lawmakers': 144,
#  'Delinquency': 145,
#  'sports': 146,
#  'Sunay': 147,
#  'ability': 148,
#  'Five': 149,
#  'adverse': 150,
#  'swim': 151,
#  'Country': 152,
#  'May': 153,
#  'physically': 154,
#  'gliders': 155,
#  'Barnett': 156,
#  'Fred': 157,
#  '$15,000,000': 158,
#  'taxes': 159,
#  'Pantas': 160,
#  'dots': 161,
#  'reiterating': 162,
#  'connect': 163,
#  'gained': 164,
#  'Rickenbaugh': 165,
#  'dean': 166,
#  'awareness': 167,
#  'hotel': 168,
#  'hazards': 169,
#  'Cooperman': 170,
#  'realize': 171,
#  'children': 172,
#  'Rayburn': 173,
#  'arrest': 174,
#  'billion': 175,
#  'blocked': 176,
#  'presumed': 177,
#  'offenses': 178,
#  '1,700': 179,
#  'special-interest': 180,
#  'generous': 181,
#  'Isodine': 182,
#  'bateau': 183,
#  "Party's": 184,
#  'Associated': 185,
#  'trial': 186,
#  'Wabash': 187,
#  'loyalty': 188,
#  "ruling's": 189,
#  'ten': 190,
#  '1-0': 191,
#  'find': 192,
#  'intensifying': 193,
#  'reserves': 194,
#  'drain': 195,
#  'Standard': 196,
#  'athletic': 197,
#  'relearns': 198,
#  'Viet': 199,
#  'surprise': 200,
#  'Ernie': 201,
#  'jazz': 202,
#  'cab': 203,
#  'script': 204,
#  'cracked': 205,
#  '5-run': 206,
#  'Newburger': 207,
#  'Riders': 208,
#  'Frank': 209,
#  'Proceeds': 210,
#  'printed': 211,
#  'delegations': 212,
#  'streaked': 213,
#  'docile': 214,
#  '1:48': 215,
#  "Kunkel's": 216,
#  '13': 217,
#  "today's": 218,
#  'limited': 219,
#  'write': 220,
#  "children's": 221,
#  'error': 222,
#  'loading': 223,
#  'Siberia': 224,
#  'uptrend': 225,
#  'tasteful': 226,
#  'incumbent': 227,
#  'surprised': 228,
#  'rightfield': 229,
#  'English': 230,
#  'developments': 231,
#  'Burgess': 232,
#  'Finalists': 233,
#  'Greenwich': 234,
#  'Toying': 235,
#  'claimed': 236,
#  'all-county': 237,
#  'Alfred': 238,
#  'Conference': 239,
#  'denied': 240,
#  'five-day': 241,
#  'conditions': 242,
#  'pay': 243,
#  'British': 244,
#  'sing': 245,
#  'cross-examination': 246,
#  'stephanotis': 247,
#  'deed': 248,
#  'Son': 249,
#  'code': 250,
#  'deductible': 251,
#  'Travelers': 252,
#  'against': 253,
#  'Maureen': 254,
#  'intensified': 255,
#  'tracing': 256,
#  'Sharon': 257,
#  '60': 258,
#  'geometrically': 259,
#  'kids': 260,
#  'funeral': 261,
#  'Marc': 262,
#  're-elected': 263,
#  'odds': 264,
#  'nonviolent': 265,
#  'proved': 266,
#  'sees': 267,
#  "Meyner's": 268,
#  'Mercer': 269,
#  'T.': 270,
#  '2825': 271,
#  'intern': 272,
#  'target': 273,
#  'smell': 274,
#  'couple': 275,
#  'powerful': 276,
#  'indictments': 277,
#  'famous': 278,
#  'integration': 279,
#  'James': 280,
#  'franchise': 281,
#  'piping': 282,
#  'Simpson': 283,
#  'Coulson': 284,
#  'Desmond': 285,
#  'Robinsonville': 286,
#  'repairs': 287,
#  'interesting': 288,
#  'Stock': 289,
#  '37': 290,
#  'rest': 291,
#  'A.A.U.': 292,
#  'prospects': 293,
#  'urgency': 294,
#  'barely': 295,
#  'Harvest': 296,
#  '56': 297,
#  'factory': 298,
#  "Blanchard's": 299,
#  'implements': 300,
#  'inscription': 301,
#  "secretary's": 302,
#  'Providence': 303,
#  'Brandeis': 304,
#  'delayed': 305,
#  'sidled': 306,
#  'happened': 307,
#  'Bldg.': 308,
#  'Should': 309,
#  'discriminatory': 310,
#  'underwriting': 311,
#  'agents': 312,
#  'Hyannis': 313,
#  'Profili': 314,
#  'viewpoint': 315,
#  'heroin': 316,
#  'away': 317,
#  'Crump': 318,
#  'universities': 319,
#  "Rayburn's": 320,
#  'receipts': 321,
#  'movements': 322,
#  'wore': 323,
#  'reputedly': 324,
#  'win': 325,
#  'Rider': 326,
#  'four': 327,
#  'sons': 328,
#  'Breuer': 329,
#  'finishing': 330,
#  'Sapio': 331,
#  'completion': 332,
#  'body': 333,
#  'Rev.': 334,
#  'slowly-mending': 335,
#  'own': 336,
#  '10': 337,
#  'privileged': 338,
#  '65': 339,
#  'deserts': 340,
#  'miss': 341,
#  'enunciate': 342,
#  'boast': 343,
#  'flower': 344,
#  'imply': 345,
#  'reason': 346,
#  'discharging': 347,
#  'deduction': 348,
#  'named': 349,
#  'Norway': 350,
#  'Club': 351,
#  'to': 352,
#  'SWC': 353,
#  'reporters': 354,
#  'canceled': 355,
#  'Mrs': 356,
#  'and': 357,
#  'reiterated': 358,
#  'National': 359,
#  'Newsom': 360,
#  'status': 361,
#  '$5000': 362,
#  'declares': 363,
#  'shoes': 364,
#  'Shriver': 365,
#  'Wallace': 366,
#  'follows': 367,
#  'entering': 368,
#  'title': 369,
#  'Giorgio': 370,
#  'receive': 371,
#  'creating': 372,
#  'top-ranking': 373,
#  'duffer': 374,
#  'someplace': 375,
#  'whether': 376,
#  'annual': 377,
#  'indicating': 378,
#  'unit': 379,
#  'front': 380,
#  'types': 381,
#  'newsman': 382,
#  'tension': 383,
#  'Smithfield': 384,
#  'modified': 385,
#  'undersea': 386,
#  'Patrolmen': 387,
#  'intimidation': 388,
#  "Nobody's": 389,
#  'Saga': 390,
#  'Chapter': 391,
#  "teams'": 392,
#  'minister': 393,
#  'Hole': 394,
#  'persecution': 395,
#  'physics': 396,
#  'Winston': 397,
#  '60,000': 398,
#  'proceeds': 399,
#  'Dilworth': 400,
#  'Terry': 401,
#  'above': 402,
#  '1600': 403,
#  'Spring': 404,
#  '100%': 405,
#  'preoccupied': 406,
#  'difficult': 407,
#  'Mayoral': 408,
#  'chairmen': 409,
#  'so-called': 410,
#  'carved': 411,
#  '31': 412,
#  "farmers'": 413,
#  'candidates': 414,
#  'wrongdoing': 415,
#  'whereby': 416,
#  '10%': 417,
#  'twelfth': 418,
#  'gift': 419,
#  'doubt': 420,
#  'very': 421,
#  '1920s': 422,
#  'Metal': 423,
#  'cotton': 424,
#  'Philadelphia': 425,
#  'frock': 426,
#  'meaningless': 427,
#  'published': 428,
#  'Pinar': 429,
#  'production': 430,
#  'recommendations': 431,
#  'Claude': 432,
#  'driveway': 433,
#  'rescind': 434,
#  'Jimmie': 435,
#  '3-hitter': 436,
#  'smashed': 437,
#  'horse': 438,
#  'sources': 439,
#  'naturally': 440,
#  'Bronx': 441,
#  "Controller's": 442,
#  'grass-green': 443,
#  'Germania': 444,
#  'slice': 445,
#  'conspirators': 446,
#  'middle': 447,
#  'TNT': 448,
#  'architecture': 449,
#  'choosing': 450,
#  'Kamens': 451,
#  'signs': 452,
#  'prominently': 453,
#  'bombs': 454,
#  'Mercury': 455,
#  '10,000,000': 456,
#  'Attilio': 457,
#  'generation': 458,
#  '$451,500': 459,
#  'Gehrig': 460,
#  'stood': 461,
#  'fourth': 462,
#  'war': 463,
#  'Net': 464,
#  'Ferdinand': 465,
#  'Dobbs': 466,
#  'Diversified': 467,
#  'governor': 468,
#  "conference's": 469,
#  '$10,000': 470,
#  "Tribe's": 471,
#  'mad': 472,
#  'quarters': 473,
#  'jury': 474,
#  'Commissioner': 475,
#  'big': 476,
#  'robbery': 477,
#  'Los': 478,
#  'Md.': 479,
#  'hoc': 480,
#  'perform': 481,
#  'Outstanding': 482,
#  'episode': 483,
#  "else's": 484,
#  'nationwide': 485,
#  'succeeds': 486,
#  'Cotten': 487,
#  'views': 488,
#  'far-flung': 489,
#  'basically': 490,
#  'professional': 491,
#  '354': 492,
#  'Hackett': 493,
#  'Spice-Nice': 494,
#  'well-established': 495,
#  'pays': 496,
#  'presides': 497,
#  'motorist': 498,
#  'Nevada': 499,
#  'showings': 500,
#  '17': 501,
#  'Estimates': 502,
#  'division': 503,
#  'Gordin': 504,
#  'Survivors': 505,
#  'operated': 506,
#  'shall': 507,
#  'head-on': 508,
#  "Stengel's": 509,
#  'Stevens': 510,
#  '80': 511,
#  "That's": 512,
#  'sound': 513,
#  'evening': 514,
#  'Pittsburgh': 515,
#  'regularly': 516,
#  'Tommy': 517,
#  'adapting': 518,
#  'Buddy': 519,
#  'Smoky': 520,
#  'Bowden': 521,
#  'rescued': 522,
#  'apparent': 523,
#  'propelling': 524,
#  'switching': 525,
#  'repeatedly': 526,
#  '$115,000': 527,
#  'sought': 528,
#  'Olvey': 529,
#  'work': 530,
#  'Hess': 531,
#  'sit': 532,
#  'popular': 533,
#  'employ': 534,
#  'predicted': 535,
#  'predict': 536,
#  'coordinate': 537,
#  'ye': 538,
#  '96': 539,
#  'Del': 540,
#  'Palm': 541,
#  'inflicted': 542,
#  'Longhorn': 543,
#  'Due': 544,
#  'ruefully': 545,
#  'camping-out': 546,
#  "I'll": 547,
#  'Army': 548,
#  'pensions': 549,
#  'manufacturers': 550,
#  'Gods': 551,
#  'appearing': 552,
#  'Taxation': 553,
#  'retrenching': 554,
#  'Serra': 555,
#  'third': 556,
#  'driving': 557,
#  'credits': 558,
#  'bestowed': 559,
#  'Agencies': 560,
#  'expansive': 561,
#  'Christine': 562,
#  'assailant': 563,
#  'wavelengths': 564,
#  'Butlers': 565,
#  'watched': 566,
#  'Treatment': 567,
#  'dilemma': 568,
#  '26-year-old': 569,
#  'purposes': 570,
#  'whipped': 571,
#  'holders': 572,
#  'Angel': 573,
#  'Merger': 574,
#  'conciliatory': 575,
#  'done': 576,
#  'tossed': 577,
#  '23d': 578,
#  'gather': 579,
#  'Seekonk': 580,
#  'notion': 581,
#  '28': 582,
#  'jotted': 583,
#  'weight': 584,
#  'comparable': 585,
#  'Nolan': 586,
#  'Kenilworth': 587,
#  'floor': 588,
#  'reactors': 589,
#  'Dresbachs': 590,
#  'rumored': 591,
#  '30': 592,
#  'Boyer': 593,
#  'different': 594,
#  'exciting': 595,
#  'Aurora': 596,
#  'swimming': 597,
#  'Opposition': 598,
#  'split-level': 599,
#  'Cocktail': 600,
#  'early': 601,
#  'obstacle': 602,
#  'conscious': 603,
#  'trust': 604,
#  'Lawrence': 605,
#  'announcing': 606,
#  'adviser': 607,
#  'salary': 608,
#  'Anson': 609,
#  'marriage': 610,
#  'their': 611,
#  'clothes': 612,
#  'compete': 613,
#  'split': 614,
#  'forever': 615,
#  'Floresville': 616,
#  'Abbey': 617,
#  'fiscal': 618,
#  'arms': 619,
#  "'55": 620,
#  'Change': 621,
#  'outspoken': 622,
#  'thinks': 623,
#  'wagging': 624,
#  'Douglas': 625,
#  'appearance': 626,
#  'Sciences': 627,
#  'ballots': 628,
#  'Kiefferm': 629,
#  'invites': 630,
#  'Letters': 631,
#  'hand': 632,
#  'democracy': 633,
#  'asserted': 634,
#  'onto': 635,
#  'Holy': 636,
#  'ex-singer': 637,
#  'Sheraton-Dallas': 638,
#  'dessert': 639,
#  'winless': 640,
#  'dark': 641,
#  'quarter-mile': 642,
#  'clashes': 643,
#  'Morris': 644,
#  'born': 645,
#  'carrying': 646,
#  'Kathleen': 647,
#  'scientific': 648,
#  'Huddle': 649,
#  'called': 650,
#  'masses': 651,
#  'Bursts': 652,
#  'foes': 653,
#  'chemicals': 654,
#  'Harrity': 655,
#  'transportation': 656,
#  'freshman': 657,
#  'Clipper': 658,
#  'Economic': 659,
#  'weapons': 660,
#  'termination': 661,
#  'constituted': 662,
#  'International': 663,
#  'Mets': 664,
#  'teaching': 665,
#  'players': 666,
#  'coming': 667,
#  'Planning': 668,
#  'effort': 669,
#  'suicide': 670,
#  'Usually': 671,
#  '273': 672,
#  'Hampton': 673,
#  'daylight': 674,
#  "we've": 675,
#  'copy': 676,
#  'severely': 677,
#  'satisfaction': 678,
#  'Ehlers': 679,
#  'turned': 680,
#  'education': 681,
#  'warhead': 682,
#  'contractors': 683,
#  '1925': 684,
#  'eve': 685,
#  'Asilomar': 686,
#  'consisted': 687,
#  'urban': 688,
#  '520-acre': 689,
#  'Local': 690,
#  'tests': 691,
#  '$2,330,000': 692,
#  'still': 693,
#  'appoint': 694,
#  'assumed': 695,
#  'A': 696,
#  'Kochaneks': 697,
#  '``': 698,
#  'exploratory': 699,
#  'abroad': 700,
#  '8,293': 701,
#  'Allegretti': 702,
#  'Section': 703,
#  'Senese': 704,
#  'peace': 705,
#  'mainly': 706,
#  'standard': 707,
#  'Samuel': 708,
#  'Legislature': 709,
#  'verify': 710,
#  '$50': 711,
#  'prepayment': 712,
#  'Prince': 713,
#  'whisking': 714,
#  'assertion': 715,
#  'absolute': 716,
#  'camps': 717,
#  'damage': 718,
#  'Twenty-one-year-old': 719,
#  '$120': 720,
#  'Report': 721,
#  'Bradford': 722,
#  'Rowley': 723,
#  '$400': 724,
#  'pounds': 725,
#  'seventh': 726,
#  'percentages': 727,
#  'rings': 728,
#  'wooden': 729,
#  'Basin': 730,
#  'tax': 731,
#  'six-point': 732,
#  'statements': 733,
#  'Much': 734,
#  'Major': 735,
#  'pertained': 736,
#  'ministerial': 737,
#  'spot': 738,
#  'Clerks': 739,
#  'Millie': 740,
#  'Foods': 741,
#  'eyebrow': 742,
#  'Ditmar': 743,
#  'she': 744,
#  'princesse': 745,
#  'Grooms': 746,
#  'research': 747,
#  'firmer': 748,
#  'Emcee': 749,
#  'make': 750,
#  'Last': 751,
#  'intercepted': 752,
#  "moment's": 753,
#  'golfer': 754,
#  'Rylie': 755,
#  'Schley': 756,
#  'Petitions': 757,
#  'rush': 758,
#  'bunter': 759,
#  'Savannah': 760,
#  'private': 761,
#  'Arrington': 762,
#  'slogan': 763,
#  'Reama': 764,
#  'seems': 765,
#  'Jane': 766,
#  'offenders': 767,
#  'businesses': 768,
#  'Cheshire': 769,
#  'ex-Mrs.': 770,
#  'weighs': 771,
#  'responsible': 772,
#  'Before': 773,
#  'Seattle': 774,
#  'nose': 775,
#  'guiding': 776,
#  'identically': 777,
#  'equally': 778,
#  'organdy': 779,
#  'schedules': 780,
#  'sculpture': 781,
#  'Eaton': 782,
#  'announced': 783,
#  'pre-Easter': 784,
#  'onslaught': 785,
#  'Utah': 786,
#  'segregation': 787,
#  '8:30': 788,
#  'Bad': 789,
#  '10-team': 790,
#  'forbids': 791,
#  '1971': 792,
#  'members': 793,
#  'manslaughter': 794,
#  'conferees': 795,
#  'fashions': 796,
#  'irregularities': 797,
#  'Distributive': 798,
#  'Beach': 799,
#  'Raesz': 800,
#  '$14': 801,
#  'taxing': 802,
#  'championships': 803,
#  "Hughes'": 804,
#  'unmeritorious': 805,
#  'its': 806,
#  'daily': 807,
#  'mile': 808,
#  'August': 809,
#  'creditable': 810,
#  'I': 811,
#  '3-0': 812,
#  'overnight': 813,
#  'janitors': 814,
#  'those': 815,
#  'immediate': 816,
#  'Hemus': 817,
#  'achieved': 818,
#  'decoration': 819,
#  "League's": 820,
#  'screen': 821,
#  'Manor': 822,
#  'arrests': 823,
#  'heritage': 824,
#  'register': 825,
#  'NYU': 826,
#  'cautioned': 827,
#  'stupidity': 828,
#  'president': 829,
#  'Inspections': 830,
#  'returning': 831,
#  'determining': 832,
#  'German': 833,
#  'Maple': 834,
#  '6-5': 835,
#  "Mills's": 836,
#  'promising': 837,
#  'settlement': 838,
#  'certainly': 839,
#  'Super': 840,
#  '5847': 841,
#  'Banks': 842,
#  'Lane': 843,
#  'pier': 844,
#  'House': 845,
#  'successful': 846,
#  'gals': 847,
#  'fields': 848,
#  'blond': 849,
#  'people': 850,
#  'Faced': 851,
#  'teams': 852,
#  'Liberal': 853,
#  'End': 854,
#  'Hal': 855,
#  'Pye': 856,
#  'eighth': 857,
#  'operators': 858,
#  'controlled': 859,
#  'Writers': 860,
#  'defendant': 861,
#  'Narragansett': 862,
#  'proper': 863,
#  'voice': 864,
#  "Thursday's": 865,
#  'Motorists': 866,
#  "Case's": 867,
#  'acting': 868,
#  'year': 869,
#  'carries': 870,
#  'pitching': 871,
#  'here': 872,
#  'characterized': 873,
#  'based': 874,
#  'They': 875,
#  'Louise': 876,
#  'fewer': 877,
#  'SW': 878,
#  'subpenas': 879,
#  'Graduate': 880,
#  'masquerade': 881,
#  'Jail': 882,
#  'all-woman': 883,
#  'breaking': 884,
#  'terms': 885,
#  'yearly': 886,
#  'hood': 887,
#  'Steeves': 888,
#  'pride': 889,
#  'Dumas': 890,
#  'Ainsley': 891,
#  'career': 892,
#  'banquet': 893,
#  'affair': 894,
#  'behind': 895,
#  'expenses': 896,
#  'orderly': 897,
#  'value': 898,
#  'mutter': 899,
#  'Innumerable': 900,
#  'learn': 901,
#  'gas': 902,
#  'application': 903,
#  'Camille': 904,
#  'ayes': 905,
#  'Oilers': 906,
#  'carry': 907,
#  'showman': 908,
#  'airfield': 909,
#  'Dr.': 910,
#  'internal': 911,
#  'senior': 912,
#  '46': 913,
#  '823': 914,
#  'Madison': 915,
#  'lover': 916,
#  'ordinary': 917,
#  'results': 918,
#  'elephants': 919,
#  'king': 920,
#  'anti-submarine': 921,
#  'tragedy': 922,
#  'chip': 923,
#  'communism': 924,
#  '1935': 925,
#  'Meet': 926,
#  'Munger': 927,
#  'laurels': 928,
#  'showmanship': 929,
#  'affect': 930,
#  'left': 931,
#  'preserve': 932,
#  'delegates': 933,
#  'codes': 934,
#  '51': 935,
#  'Reeder': 936,
#  'Anna': 937,
#  'Jimmy': 938,
#  'run-up': 939,
#  'Bassi': 940,
#  '9-7': 941,
#  "club's": 942,
#  'behavior': 943,
#  'youthful': 944,
#  'overwhelmingly': 945,
#  'bayonet': 946,
#  'provisional': 947,
#  'attack': 948,
#  'conspiracy': 949,
#  'polled': 950,
#  'colleges': 951,
#  'Carnival': 952,
#  'Symphony': 953,
#  'asking': 954,
#  'netted': 955,
#  'figuring': 956,
#  'Black': 957,
#  'admission': 958,
#  'caskets': 959,
#  'keyhole': 960,
#  'Walsh': 961,
#  'Flock': 962,
#  'Parichy': 963,
#  "House's": 964,
#  'robbed': 965,
#  'bowl': 966,
#  'Republican-controlled': 967,
#  'experimental': 968,
#  'saws': 969,
#  'Legion': 970,
#  'water': 971,
#  'writer': 972,
#  'parent': 973,
#  'Moving': 974,
#  'aged-care': 975,
#  'pl.': 976,
#  'Kas.': 977,
#  'Tom': 978,
#  'quarterly': 979,
#  'obligation': 980,
#  'Anniston': 981,
#  'family': 982,
#  'Detroit': 983,
#  'solution': 984,
#  'Cedar': 985,
#  'Rex': 986,
#  'Tractor': 987,
#  'enjoy': 988,
#  'services': 989,
#  'adjournment': 990,
#  'fund-raiser': 991,
#  'Tim': 992,
#  'supporters': 993,
#  'P.M.': 994,
#  'acquittal': 995,
#  'Olivia': 996,
#  'donated': 997,
#  'Lay': 998,
#  '13-8': 999,
#  ...}

# %% [markdown]
# ### 2.4 Create index2word dictionary

# %%
index2word = {v:k for k, v in word2index.items()}

# %%
index2word
# Out:
# {0: '<UNK>',
#  1: 'hooked',
#  2: 'jewels',
#  3: 'Affairs',
#  4: 'chef',
#  5: 'crosswalk',
#  6: 'controversial',
#  7: 'Troop',
#  8: 'amicable',
#  9: 'F',
#  10: 'Johnson',
#  11: 'segregated',
#  12: 'eliminating',
#  13: '300',
#  14: 'diem',
#  15: 'believed',
#  16: 'Military',
#  17: '300-450',
#  18: 'Blumberg',
#  19: 'doubted',
#  20: 'industries',
#  21: 'created',
#  22: 'death',
#  23: 'beliefs',
#  24: '963',
#  25: 'none',
#  26: 'attracted',
#  27: 'price',
#  28: '205-pound',
#  29: 'governing',
#  30: 'notarized',
#  31: 'US',
#  32: 'secret',
#  33: 'hire',
#  34: 'ran',
#  35: 'items',
#  36: 'cannot',
#  37: 'checks',
#  38: 'dentistry',
#  39: 'Gentile',
#  40: 'ultimate',
#  41: 'Mustang',
#  42: 'increase',
#  43: 'calmest',
#  44: 'performing',
#  45: 'Elks',
#  46: 'team',
#  47: 'coup',
#  48: 'Duren',
#  49: 'long-time',
#  50: 'sentencing',
#  51: 'Spahn',
#  52: 'Home',
#  53: 'protested',
#  54: "Stein's",
#  55: 'fullbacking',
#  56: 'newspapers',
#  57: 'rapped',
#  58: '4-year-old',
#  59: 'purse',
#  60: "Canada's",
#  61: 'Turandot',
#  62: 'Webster',
#  63: 'allies',
#  64: 'fiance',
#  65: 'computed',
#  66: 'Split',
#  67: 'precedent',
#  68: 'Snellville',
#  69: 'Canadian',
#  70: 'mentioned',
#  71: 'Time',
#  72: 'youngest',
#  73: 'Examiner',
#  74: 'drafted',
#  75: 'Foundation',
#  76: '$109',
#  77: 'fence',
#  78: 'reportedly',
#  79: '$200,000',
#  80: 'scrimmaged',
#  81: 'North',
#  82: 'aggravates',
#  83: 'jointly',
#  84: 'taken',
#  85: 'every',
#  86: 'Hubbell',
#  87: 'apprentice',
#  88: 'receives',
#  89: 'revealed',
#  90: 'penalized',
#  91: 'Terral',
#  92: 'Nov.',
#  93: 'availability',
#  94: 'Griffin',
#  95: 'Dussa',
#  96: 'Pelham',
#  97: 'leaders',
#  98: 'god-like',
#  99: 'teach',
#  100: 'Friends',
#  101: 'Herbert',
#  102: 'direction',
#  103: 'Jordan',
#  104: 'comfort',
#  105: 'hired',
#  106: 'Whipple',
#  107: 'Bermuda',
#  108: 'deterrent',
#  109: 'love',
#  110: 'chose',
#  111: 'development',
#  112: '15-year-old',
#  113: 'AF',
#  114: 'Portugal',
#  115: 'properties',
#  116: 'scholastically',
#  117: 'rain',
#  118: 'republic',
#  119: 'nuclear',
#  120: 'Lisle',
#  121: 'favored',
#  122: 'dedicated',
#  123: 'Voters',
#  124: 'collections',
#  125: 'alternate',
#  126: 'Inheriting',
#  127: 'Sheeran',
#  128: 'church-state',
#  129: 'warmed',
#  130: 'View',
#  131: 'eminent',
#  132: 'sales',
#  133: 'Raymondville',
#  134: 'waved',
#  135: 'steep',
#  136: 'lace',
#  137: 'Winchell',
#  138: 'Kelsey',
#  139: 'Cooperation',
#  140: 'burrowed',
#  141: 'indecisive',
#  142: 'stand',
#  143: 'trucks',
#  144: 'lawmakers',
#  145: 'Delinquency',
#  146: 'sports',
#  147: 'Sunay',
#  148: 'ability',
#  149: 'Five',
#  150: 'adverse',
#  151: 'swim',
#  152: 'Country',
#  153: 'May',
#  154: 'physically',
#  155: 'gliders',
#  156: 'Barnett',
#  157: 'Fred',
#  158: '$15,000,000',
#  159: 'taxes',
#  160: 'Pantas',
#  161: 'dots',
#  162: 'reiterating',
#  163: 'connect',
#  164: 'gained',
#  165: 'Rickenbaugh',
#  166: 'dean',
#  167: 'awareness',
#  168: 'hotel',
#  169: 'hazards',
#  170: 'Cooperman',
#  171: 'realize',
#  172: 'children',
#  173: 'Rayburn',
#  174: 'arrest',
#  175: 'billion',
#  176: 'blocked',
#  177: 'presumed',
#  178: 'offenses',
#  179: '1,700',
#  180: 'special-interest',
#  181: 'generous',
#  182: 'Isodine',
#  183: 'bateau',
#  184: "Party's",
#  185: 'Associated',
#  186: 'trial',
#  187: 'Wabash',
#  188: 'loyalty',
#  189: "ruling's",
#  190: 'ten',
#  191: '1-0',
#  192: 'find',
#  193: 'intensifying',
#  194: 'reserves',
#  195: 'drain',
#  196: 'Standard',
#  197: 'athletic',
#  198: 'relearns',
#  199: 'Viet',
#  200: 'surprise',
#  201: 'Ernie',
#  202: 'jazz',
#  203: 'cab',
#  204: 'script',
#  205: 'cracked',
#  206: '5-run',
#  207: 'Newburger',
#  208: 'Riders',
#  209: 'Frank',
#  210: 'Proceeds',
#  211: 'printed',
#  212: 'delegations',
#  213: 'streaked',
#  214: 'docile',
#  215: '1:48',
#  216: "Kunkel's",
#  217: '13',
#  218: "today's",
#  219: 'limited',
#  220: 'write',
#  221: "children's",
#  222: 'error',
#  223: 'loading',
#  224: 'Siberia',
#  225: 'uptrend',
#  226: 'tasteful',
#  227: 'incumbent',
#  228: 'surprised',
#  229: 'rightfield',
#  230: 'English',
#  231: 'developments',
#  232: 'Burgess',
#  233: 'Finalists',
#  234: 'Greenwich',
#  235: 'Toying',
#  236: 'claimed',
#  237: 'all-county',
#  238: 'Alfred',
#  239: 'Conference',
#  240: 'denied',
#  241: 'five-day',
#  242: 'conditions',
#  243: 'pay',
#  244: 'British',
#  245: 'sing',
#  246: 'cross-examination',
#  247: 'stephanotis',
#  248: 'deed',
#  249: 'Son',
#  250: 'code',
#  251: 'deductible',
#  252: 'Travelers',
#  253: 'against',
#  254: 'Maureen',
#  255: 'intensified',
#  256: 'tracing',
#  257: 'Sharon',
#  258: '60',
#  259: 'geometrically',
#  260: 'kids',
#  261: 'funeral',
#  262: 'Marc',
#  263: 're-elected',
#  264: 'odds',
#  265: 'nonviolent',
#  266: 'proved',
#  267: 'sees',
#  268: "Meyner's",
#  269: 'Mercer',
#  270: 'T.',
#  271: '2825',
#  272: 'intern',
#  273: 'target',
#  274: 'smell',
#  275: 'couple',
#  276: 'powerful',
#  277: 'indictments',
#  278: 'famous',
#  279: 'integration',
#  280: 'James',
#  281: 'franchise',
#  282: 'piping',
#  283: 'Simpson',
#  284: 'Coulson',
#  285: 'Desmond',
#  286: 'Robinsonville',
#  287: 'repairs',
#  288: 'interesting',
#  289: 'Stock',
#  290: '37',
#  291: 'rest',
#  292: 'A.A.U.',
#  293: 'prospects',
#  294: 'urgency',
#  295: 'barely',
#  296: 'Harvest',
#  297: '56',
#  298: 'factory',
#  299: "Blanchard's",
#  300: 'implements',
#  301: 'inscription',
#  302: "secretary's",
#  303: 'Providence',
#  304: 'Brandeis',
#  305: 'delayed',
#  306: 'sidled',
#  307: 'happened',
#  308: 'Bldg.',
#  309: 'Should',
#  310: 'discriminatory',
#  311: 'underwriting',
#  312: 'agents',
#  313: 'Hyannis',
#  314: 'Profili',
#  315: 'viewpoint',
#  316: 'heroin',
#  317: 'away',
#  318: 'Crump',
#  319: 'universities',
#  320: "Rayburn's",
#  321: 'receipts',
#  322: 'movements',
#  323: 'wore',
#  324: 'reputedly',
#  325: 'win',
#  326: 'Rider',
#  327: 'four',
#  328: 'sons',
#  329: 'Breuer',
#  330: 'finishing',
#  331: 'Sapio',
#  332: 'completion',
#  333: 'body',
#  334: 'Rev.',
#  335: 'slowly-mending',
#  336: 'own',
#  337: '10',
#  338: 'privileged',
#  339: '65',
#  340: 'deserts',
#  341: 'miss',
#  342: 'enunciate',
#  343: 'boast',
#  344: 'flower',
#  345: 'imply',
#  346: 'reason',
#  347: 'discharging',
#  348: 'deduction',
#  349: 'named',
#  350: 'Norway',
#  351: 'Club',
#  352: 'to',
#  353: 'SWC',
#  354: 'reporters',
#  355: 'canceled',
#  356: 'Mrs',
#  357: 'and',
#  358: 'reiterated',
#  359: 'National',
#  360: 'Newsom',
#  361: 'status',
#  362: '$5000',
#  363: 'declares',
#  364: 'shoes',
#  365: 'Shriver',
#  366: 'Wallace',
#  367: 'follows',
#  368: 'entering',
#  369: 'title',
#  370: 'Giorgio',
#  371: 'receive',
#  372: 'creating',
#  373: 'top-ranking',
#  374: 'duffer',
#  375: 'someplace',
#  376: 'whether',
#  377: 'annual',
#  378: 'indicating',
#  379: 'unit',
#  380: 'front',
#  381: 'types',
#  382: 'newsman',
#  383: 'tension',
#  384: 'Smithfield',
#  385: 'modified',
#  386: 'undersea',
#  387: 'Patrolmen',
#  388: 'intimidation',
#  389: "Nobody's",
#  390: 'Saga',
#  391: 'Chapter',
#  392: "teams'",
#  393: 'minister',
#  394: 'Hole',
#  395: 'persecution',
#  396: 'physics',
#  397: 'Winston',
#  398: '60,000',
#  399: 'proceeds',
#  400: 'Dilworth',
#  401: 'Terry',
#  402: 'above',
#  403: '1600',
#  404: 'Spring',
#  405: '100%',
#  406: 'preoccupied',
#  407: 'difficult',
#  408: 'Mayoral',
#  409: 'chairmen',
#  410: 'so-called',
#  411: 'carved',
#  412: '31',
#  413: "farmers'",
#  414: 'candidates',
#  415: 'wrongdoing',
#  416: 'whereby',
#  417: '10%',
#  418: 'twelfth',
#  419: 'gift',
#  420: 'doubt',
#  421: 'very',
#  422: '1920s',
#  423: 'Metal',
#  424: 'cotton',
#  425: 'Philadelphia',
#  426: 'frock',
#  427: 'meaningless',
#  428: 'published',
#  429: 'Pinar',
#  430: 'production',
#  431: 'recommendations',
#  432: 'Claude',
#  433: 'driveway',
#  434: 'rescind',
#  435: 'Jimmie',
#  436: '3-hitter',
#  437: 'smashed',
#  438: 'horse',
#  439: 'sources',
#  440: 'naturally',
#  441: 'Bronx',
#  442: "Controller's",
#  443: 'grass-green',
#  444: 'Germania',
#  445: 'slice',
#  446: 'conspirators',
#  447: 'middle',
#  448: 'TNT',
#  449: 'architecture',
#  450: 'choosing',
#  451: 'Kamens',
#  452: 'signs',
#  453: 'prominently',
#  454: 'bombs',
#  455: 'Mercury',
#  456: '10,000,000',
#  457: 'Attilio',
#  458: 'generation',
#  459: '$451,500',
#  460: 'Gehrig',
#  461: 'stood',
#  462: 'fourth',
#  463: 'war',
#  464: 'Net',
#  465: 'Ferdinand',
#  466: 'Dobbs',
#  467: 'Diversified',
#  468: 'governor',
#  469: "conference's",
#  470: '$10,000',
#  471: "Tribe's",
#  472: 'mad',
#  473: 'quarters',
#  474: 'jury',
#  475: 'Commissioner',
#  476: 'big',
#  477: 'robbery',
#  478: 'Los',
#  479: 'Md.',
#  480: 'hoc',
#  481: 'perform',
#  482: 'Outstanding',
#  483: 'episode',
#  484: "else's",
#  485: 'nationwide',
#  486: 'succeeds',
#  487: 'Cotten',
#  488: 'views',
#  489: 'far-flung',
#  490: 'basically',
#  491: 'professional',
#  492: '354',
#  493: 'Hackett',
#  494: 'Spice-Nice',
#  495: 'well-established',
#  496: 'pays',
#  497: 'presides',
#  498: 'motorist',
#  499: 'Nevada',
#  500: 'showings',
#  501: '17',
#  502: 'Estimates',
#  503: 'division',
#  504: 'Gordin',
#  505: 'Survivors',
#  506: 'operated',
#  507: 'shall',
#  508: 'head-on',
#  509: "Stengel's",
#  510: 'Stevens',
#  511: '80',
#  512: "That's",
#  513: 'sound',
#  514: 'evening',
#  515: 'Pittsburgh',
#  516: 'regularly',
#  517: 'Tommy',
#  518: 'adapting',
#  519: 'Buddy',
#  520: 'Smoky',
#  521: 'Bowden',
#  522: 'rescued',
#  523: 'apparent',
#  524: 'propelling',
#  525: 'switching',
#  526: 'repeatedly',
#  527: '$115,000',
#  528: 'sought',
#  529: 'Olvey',
#  530: 'work',
#  531: 'Hess',
#  532: 'sit',
#  533: 'popular',
#  534: 'employ',
#  535: 'predicted',
#  536: 'predict',
#  537: 'coordinate',
#  538: 'ye',
#  539: '96',
#  540: 'Del',
#  541: 'Palm',
#  542: 'inflicted',
#  543: 'Longhorn',
#  544: 'Due',
#  545: 'ruefully',
#  546: 'camping-out',
#  547: "I'll",
#  548: 'Army',
#  549: 'pensions',
#  550: 'manufacturers',
#  551: 'Gods',
#  552: 'appearing',
#  553: 'Taxation',
#  554: 'retrenching',
#  555: 'Serra',
#  556: 'third',
#  557: 'driving',
#  558: 'credits',
#  559: 'bestowed',
#  560: 'Agencies',
#  561: 'expansive',
#  562: 'Christine',
#  563: 'assailant',
#  564: 'wavelengths',
#  565: 'Butlers',
#  566: 'watched',
#  567: 'Treatment',
#  568: 'dilemma',
#  569: '26-year-old',
#  570: 'purposes',
#  571: 'whipped',
#  572: 'holders',
#  573: 'Angel',
#  574: 'Merger',
#  575: 'conciliatory',
#  576: 'done',
#  577: 'tossed',
#  578: '23d',
#  579: 'gather',
#  580: 'Seekonk',
#  581: 'notion',
#  582: '28',
#  583: 'jotted',
#  584: 'weight',
#  585: 'comparable',
#  586: 'Nolan',
#  587: 'Kenilworth',
#  588: 'floor',
#  589: 'reactors',
#  590: 'Dresbachs',
#  591: 'rumored',
#  592: '30',
#  593: 'Boyer',
#  594: 'different',
#  595: 'exciting',
#  596: 'Aurora',
#  597: 'swimming',
#  598: 'Opposition',
#  599: 'split-level',
#  600: 'Cocktail',
#  601: 'early',
#  602: 'obstacle',
#  603: 'conscious',
#  604: 'trust',
#  605: 'Lawrence',
#  606: 'announcing',
#  607: 'adviser',
#  608: 'salary',
#  609: 'Anson',
#  610: 'marriage',
#  611: 'their',
#  612: 'clothes',
#  613: 'compete',
#  614: 'split',
#  615: 'forever',
#  616: 'Floresville',
#  617: 'Abbey',
#  618: 'fiscal',
#  619: 'arms',
#  620: "'55",
#  621: 'Change',
#  622: 'outspoken',
#  623: 'thinks',
#  624: 'wagging',
#  625: 'Douglas',
#  626: 'appearance',
#  627: 'Sciences',
#  628: 'ballots',
#  629: 'Kiefferm',
#  630: 'invites',
#  631: 'Letters',
#  632: 'hand',
#  633: 'democracy',
#  634: 'asserted',
#  635: 'onto',
#  636: 'Holy',
#  637: 'ex-singer',
#  638: 'Sheraton-Dallas',
#  639: 'dessert',
#  640: 'winless',
#  641: 'dark',
#  642: 'quarter-mile',
#  643: 'clashes',
#  644: 'Morris',
#  645: 'born',
#  646: 'carrying',
#  647: 'Kathleen',
#  648: 'scientific',
#  649: 'Huddle',
#  650: 'called',
#  651: 'masses',
#  652: 'Bursts',
#  653: 'foes',
#  654: 'chemicals',
#  655: 'Harrity',
#  656: 'transportation',
#  657: 'freshman',
#  658: 'Clipper',
#  659: 'Economic',
#  660: 'weapons',
#  661: 'termination',
#  662: 'constituted',
#  663: 'International',
#  664: 'Mets',
#  665: 'teaching',
#  666: 'players',
#  667: 'coming',
#  668: 'Planning',
#  669: 'effort',
#  670: 'suicide',
#  671: 'Usually',
#  672: '273',
#  673: 'Hampton',
#  674: 'daylight',
#  675: "we've",
#  676: 'copy',
#  677: 'severely',
#  678: 'satisfaction',
#  679: 'Ehlers',
#  680: 'turned',
#  681: 'education',
#  682: 'warhead',
#  683: 'contractors',
#  684: '1925',
#  685: 'eve',
#  686: 'Asilomar',
#  687: 'consisted',
#  688: 'urban',
#  689: '520-acre',
#  690: 'Local',
#  691: 'tests',
#  692: '$2,330,000',
#  693: 'still',
#  694: 'appoint',
#  695: 'assumed',
#  696: 'A',
#  697: 'Kochaneks',
#  698: '``',
#  699: 'exploratory',
#  700: 'abroad',
#  701: '8,293',
#  702: 'Allegretti',
#  703: 'Section',
#  704: 'Senese',
#  705: 'peace',
#  706: 'mainly',
#  707: 'standard',
#  708: 'Samuel',
#  709: 'Legislature',
#  710: 'verify',
#  711: '$50',
#  712: 'prepayment',
#  713: 'Prince',
#  714: 'whisking',
#  715: 'assertion',
#  716: 'absolute',
#  717: 'camps',
#  718: 'damage',
#  719: 'Twenty-one-year-old',
#  720: '$120',
#  721: 'Report',
#  722: 'Bradford',
#  723: 'Rowley',
#  724: '$400',
#  725: 'pounds',
#  726: 'seventh',
#  727: 'percentages',
#  728: 'rings',
#  729: 'wooden',
#  730: 'Basin',
#  731: 'tax',
#  732: 'six-point',
#  733: 'statements',
#  734: 'Much',
#  735: 'Major',
#  736: 'pertained',
#  737: 'ministerial',
#  738: 'spot',
#  739: 'Clerks',
#  740: 'Millie',
#  741: 'Foods',
#  742: 'eyebrow',
#  743: 'Ditmar',
#  744: 'she',
#  745: 'princesse',
#  746: 'Grooms',
#  747: 'research',
#  748: 'firmer',
#  749: 'Emcee',
#  750: 'make',
#  751: 'Last',
#  752: 'intercepted',
#  753: "moment's",
#  754: 'golfer',
#  755: 'Rylie',
#  756: 'Schley',
#  757: 'Petitions',
#  758: 'rush',
#  759: 'bunter',
#  760: 'Savannah',
#  761: 'private',
#  762: 'Arrington',
#  763: 'slogan',
#  764: 'Reama',
#  765: 'seems',
#  766: 'Jane',
#  767: 'offenders',
#  768: 'businesses',
#  769: 'Cheshire',
#  770: 'ex-Mrs.',
#  771: 'weighs',
#  772: 'responsible',
#  773: 'Before',
#  774: 'Seattle',
#  775: 'nose',
#  776: 'guiding',
#  777: 'identically',
#  778: 'equally',
#  779: 'organdy',
#  780: 'schedules',
#  781: 'sculpture',
#  782: 'Eaton',
#  783: 'announced',
#  784: 'pre-Easter',
#  785: 'onslaught',
#  786: 'Utah',
#  787: 'segregation',
#  788: '8:30',
#  789: 'Bad',
#  790: '10-team',
#  791: 'forbids',
#  792: '1971',
#  793: 'members',
#  794: 'manslaughter',
#  795: 'conferees',
#  796: 'fashions',
#  797: 'irregularities',
#  798: 'Distributive',
#  799: 'Beach',
#  800: 'Raesz',
#  801: '$14',
#  802: 'taxing',
#  803: 'championships',
#  804: "Hughes'",
#  805: 'unmeritorious',
#  806: 'its',
#  807: 'daily',
#  808: 'mile',
#  809: 'August',
#  810: 'creditable',
#  811: 'I',
#  812: '3-0',
#  813: 'overnight',
#  814: 'janitors',
#  815: 'those',
#  816: 'immediate',
#  817: 'Hemus',
#  818: 'achieved',
#  819: 'decoration',
#  820: "League's",
#  821: 'screen',
#  822: 'Manor',
#  823: 'arrests',
#  824: 'heritage',
#  825: 'register',
#  826: 'NYU',
#  827: 'cautioned',
#  828: 'stupidity',
#  829: 'president',
#  830: 'Inspections',
#  831: 'returning',
#  832: 'determining',
#  833: 'German',
#  834: 'Maple',
#  835: '6-5',
#  836: "Mills's",
#  837: 'promising',
#  838: 'settlement',
#  839: 'certainly',
#  840: 'Super',
#  841: '5847',
#  842: 'Banks',
#  843: 'Lane',
#  844: 'pier',
#  845: 'House',
#  846: 'successful',
#  847: 'gals',
#  848: 'fields',
#  849: 'blond',
#  850: 'people',
#  851: 'Faced',
#  852: 'teams',
#  853: 'Liberal',
#  854: 'End',
#  855: 'Hal',
#  856: 'Pye',
#  857: 'eighth',
#  858: 'operators',
#  859: 'controlled',
#  860: 'Writers',
#  861: 'defendant',
#  862: 'Narragansett',
#  863: 'proper',
#  864: 'voice',
#  865: "Thursday's",
#  866: 'Motorists',
#  867: "Case's",
#  868: 'acting',
#  869: 'year',
#  870: 'carries',
#  871: 'pitching',
#  872: 'here',
#  873: 'characterized',
#  874: 'based',
#  875: 'They',
#  876: 'Louise',
#  877: 'fewer',
#  878: 'SW',
#  879: 'subpenas',
#  880: 'Graduate',
#  881: 'masquerade',
#  882: 'Jail',
#  883: 'all-woman',
#  884: 'breaking',
#  885: 'terms',
#  886: 'yearly',
#  887: 'hood',
#  888: 'Steeves',
#  889: 'pride',
#  890: 'Dumas',
#  891: 'Ainsley',
#  892: 'career',
#  893: 'banquet',
#  894: 'affair',
#  895: 'behind',
#  896: 'expenses',
#  897: 'orderly',
#  898: 'value',
#  899: 'mutter',
#  900: 'Innumerable',
#  901: 'learn',
#  902: 'gas',
#  903: 'application',
#  904: 'Camille',
#  905: 'ayes',
#  906: 'Oilers',
#  907: 'carry',
#  908: 'showman',
#  909: 'airfield',
#  910: 'Dr.',
#  911: 'internal',
#  912: 'senior',
#  913: '46',
#  914: '823',
#  915: 'Madison',
#  916: 'lover',
#  917: 'ordinary',
#  918: 'results',
#  919: 'elephants',
#  920: 'king',
#  921: 'anti-submarine',
#  922: 'tragedy',
#  923: 'chip',
#  924: 'communism',
#  925: '1935',
#  926: 'Meet',
#  927: 'Munger',
#  928: 'laurels',
#  929: 'showmanship',
#  930: 'affect',
#  931: 'left',
#  932: 'preserve',
#  933: 'delegates',
#  934: 'codes',
#  935: '51',
#  936: 'Reeder',
#  937: 'Anna',
#  938: 'Jimmy',
#  939: 'run-up',
#  940: 'Bassi',
#  941: '9-7',
#  942: "club's",
#  943: 'behavior',
#  944: 'youthful',
#  945: 'overwhelmingly',
#  946: 'bayonet',
#  947: 'provisional',
#  948: 'attack',
#  949: 'conspiracy',
#  950: 'polled',
#  951: 'colleges',
#  952: 'Carnival',
#  953: 'Symphony',
#  954: 'asking',
#  955: 'netted',
#  956: 'figuring',
#  957: 'Black',
#  958: 'admission',
#  959: 'caskets',
#  960: 'keyhole',
#  961: 'Walsh',
#  962: 'Flock',
#  963: 'Parichy',
#  964: "House's",
#  965: 'robbed',
#  966: 'bowl',
#  967: 'Republican-controlled',
#  968: 'experimental',
#  969: 'saws',
#  970: 'Legion',
#  971: 'water',
#  972: 'writer',
#  973: 'parent',
#  974: 'Moving',
#  975: 'aged-care',
#  976: 'pl.',
#  977: 'Kas.',
#  978: 'Tom',
#  979: 'quarterly',
#  980: 'obligation',
#  981: 'Anniston',
#  982: 'family',
#  983: 'Detroit',
#  984: 'solution',
#  985: 'Cedar',
#  986: 'Rex',
#  987: 'Tractor',
#  988: 'enjoy',
#  989: 'services',
#  990: 'adjournment',
#  991: 'fund-raiser',
#  992: 'Tim',
#  993: 'supporters',
#  994: 'P.M.',
#  995: 'acquittal',
#  996: 'Olivia',
#  997: 'donated',
#  998: 'Lay',
#  999: '13-8',
#  ...}

# %% [markdown]
# ## 3. Create a Co-occurrence matrix

# %% [markdown]
# ### 3.1 Create a word counter

# %%
from collections import Counter
counter_word = Counter(flatten(corpus_tokenized))

# %%
counter_word
# Out:
# Counter({'The': 557,
#          'Fulton': 14,
#          'County': 32,
#          'Grand': 4,
#          'Jury': 2,
#          'said': 360,
#          'Friday': 33,
#          'an': 188,
#          'investigation': 8,
#          'of': 1856,
#          "Atlanta's": 2,
#          'recent': 13,
#          'primary': 15,
#          'election': 35,
#          'produced': 1,
#          '``': 479,
#          'no': 68,
#          'evidence': 13,
#          "''": 459,
#          'that': 476,
#          'any': 39,
#          'irregularities': 3,
#          'took': 25,
#          'place': 14,
#          '.': 2595,
#          'jury': 44,
#          'further': 11,
#          'in': 1230,
#          'term-end': 1,
#          'presentments': 1,
#          'the': 3511,
#          'City': 37,
#          'Executive': 3,
#          'Committee': 22,
#          ',': 3320,
#          'which': 150,
#          'had': 151,
#          'over-all': 2,
#          'charge': 13,
#          'deserves': 2,
#          'praise': 2,
#          'and': 1343,
#          'thanks': 5,
#          'Atlanta': 14,
#          'for': 662,
#          'manner': 3,
#          'was': 489,
#          'conducted': 3,
#          'September-October': 1,
#          'term': 12,
#          'been': 144,
#          'charged': 12,
#          'by': 328,
#          'Superior': 5,
#          'Court': 25,
#          'Judge': 20,
#          'Durwood': 1,
#          'Pye': 1,
#          'to': 1303,
#          'investigate': 3,
#          'reports': 9,
#          'possible': 20,
#          'hard-fought': 1,
#          'won': 16,
#          'Mayor-nominate': 1,
#          'Ivan': 2,
#          'Allen': 5,
#          'Jr.': 41,
#          'Only': 6,
#          'a': 1296,
#          'relative': 2,
#          'handful': 1,
#          'such': 46,
#          'received': 27,
#          'considering': 2,
#          'widespread': 2,
#          'interest': 13,
#          'number': 22,
#          'voters': 11,
#          'size': 3,
#          'this': 158,
#          'city': 45,
#          'it': 213,
#          'did': 38,
#          'find': 10,
#          'many': 31,
#          "Georgia's": 5,
#          'registration': 1,
#          'laws': 11,
#          'are': 176,
#          'outmoded': 1,
#          'or': 88,
#          'inadequate': 2,
#          'often': 5,
#          'ambiguous': 1,
#          'It': 75,
#          'recommended': 8,
#          'legislators': 8,
#          'act': 6,
#          'have': 152,
#          'these': 29,
#          'studied': 6,
#          'revised': 2,
#          'end': 18,
#          'modernizing': 1,
#          'improving': 2,
#          'them': 50,
#          'grand': 12,
#          'commented': 5,
#          'on': 423,
#          'other': 88,
#          'topics': 2,
#          'among': 19,
#          'purchasing': 2,
#          'departments': 2,
#          'well': 21,
#          'operated': 4,
#          'follow': 7,
#          'generally': 10,
#          'accepted': 3,
#          'practices': 4,
#          'inure': 1,
#          'best': 18,
#          'both': 33,
#          'governments': 1,
#          'Merger': 1,
#          'proposed': 16,
#          'However': 7,
#          'believes': 7,
#          'two': 111,
#          'offices': 4,
#          'should': 47,
#          'be': 362,
#          'combined': 9,
#          'achieve': 4,
#          'greater': 9,
#          'efficiency': 1,
#          'reduce': 5,
#          'cost': 14,
#          'administration': 49,
#          'Purchasing': 1,
#          'Department': 18,
#          'is': 408,
#          'lacking': 3,
#          'experienced': 2,
#          'clerical': 3,
#          'personnel': 8,
#          'as': 309,
#          'result': 16,
#          'policies': 6,
#          'urged': 9,
#          'take': 29,
#          'steps': 7,
#          'remedy': 1,
#          'problem': 18,
#          'Implementation': 1,
#          'automobile': 4,
#          'title': 2,
#          'law': 28,
#          'also': 88,
#          'outgoing': 2,
#          'next': 29,
#          'Legislature': 19,
#          'provide': 18,
#          'enabling': 5,
#          'funds': 20,
#          're-set': 1,
#          'effective': 8,
#          'date': 12,
#          'so': 34,
#          'orderly': 3,
#          'implementation': 1,
#          'may': 32,
#          'effected': 1,
#          'swipe': 1,
#          'at': 378,
#          'State': 50,
#          'Welfare': 3,
#          "Department's": 2,
#          'handling': 2,
#          'federal': 31,
#          'granted': 2,
#          'child': 6,
#          'welfare': 11,
#          'services': 10,
#          'foster': 1,
#          'homes': 7,
#          'This': 38,
#          'one': 104,
#          'major': 15,
#          'items': 4,
#          'general': 24,
#          'assistance': 6,
#          'program': 49,
#          'but': 93,
#          'has': 204,
#          'seen': 3,
#          'fit': 1,
#          'distribute': 2,
#          'through': 30,
#          'all': 82,
#          'counties': 12,
#          'state': 76,
#          'with': 313,
#          'exception': 3,
#          'receives': 1,
#          'none': 5,
#          'money': 23,
#          'jurors': 4,
#          'they': 107,
#          'realize': 1,
#          'proportionate': 1,
#          'distribution': 5,
#          'might': 16,
#          'disable': 1,
#          'our': 29,
#          'less': 7,
#          'populous': 3,
#          'Nevertheless': 1,
#          'we': 49,
#          'feel': 10,
#          'future': 18,
#          'receive': 15,
#          'some': 60,
#          'portion': 2,
#          'available': 4,
#          'Failure': 2,
#          'do': 33,
#          'will': 289,
#          'continue': 7,
#          'disproportionate': 1,
#          'burden': 1,
#          'taxpayers': 5,
#          "ordinary's": 1,
#          'court': 26,
#          'under': 51,
#          'fire': 21,
#          'its': 104,
#          'appointment': 8,
#          'appraisers': 1,
#          'guardians': 2,
#          'administrators': 1,
#          'awarding': 1,
#          'fees': 13,
#          'compensation': 1,
#          'Wards': 1,
#          'protected': 1,
#          'found': 22,
#          'incorporated': 1,
#          'into': 74,
#          'operating': 1,
#          'procedures': 4,
#          'recommendations': 6,
#          'previous': 9,
#          'juries': 1,
#          'Bar': 2,
#          'Association': 14,
#          'interim': 1,
#          'citizens': 4,
#          'committee': 33,
#          'These': 8,
#          'actions': 4,
#          'serve': 1,
#          'protect': 1,
#          'fact': 9,
#          'effect': 10,
#          "court's": 1,
#          'wards': 1,
#          'from': 211,
#          'undue': 1,
#          'costs': 11,
#          'appointed': 5,
#          'elected': 10,
#          'servants': 5,
#          'unmeritorious': 1,
#          'criticisms': 2,
#          'Regarding': 1,
#          'new': 88,
#          'multi-million-dollar': 1,
#          'airport': 3,
#          'when': 85,
#          'management': 4,
#          'takes': 5,
#          'Jan.': 12,
#          '1': 42,
#          'eliminate': 4,
#          'political': 18,
#          'influences': 1,
#          'not': 142,
#          'elaborate': 3,
#          'added': 25,
#          'there': 75,
#          'periodic': 1,
#          'surveillance': 1,
#          'pricing': 1,
#          'concessionaires': 1,
#          'purpose': 3,
#          'keeping': 4,
#          'prices': 9,
#          'reasonable': 1,
#          'Ask': 1,
#          'jail': 5,
#          'deputies': 2,
#          'On': 16,
#          'matters': 1,
#          ':': 65,
#          '(': 80,
#          ')': 79,
#          'Four': 5,
#          'additional': 10,
#          'employed': 5,
#          'Jail': 2,
#          'doctor': 3,
#          'medical': 17,
#          'intern': 1,
#          'extern': 1,
#          'night': 57,
#          'weekend': 7,
#          'duty': 2,
#          '2': 22,
#          'work': 44,
#          'officials': 10,
#          'pass': 12,
#          'legislation': 8,
#          'permit': 4,
#          'establishment': 4,
#          'fair': 10,
#          'equitable': 1,
#          'pension': 5,
#          'plan': 39,
#          'employes': 7,
#          'praised': 2,
#          'operation': 10,
#          'Police': 9,
#          'Tax': 5,
#          "Commissioner's": 1,
#          'Office': 3,
#          'Bellwood': 1,
#          'Alpharetta': 1,
#          'prison': 7,
#          'farms': 3,
#          'Grady': 5,
#          'Hospital': 21,
#          'Health': 4,
#          'Mayor': 17,
#          'William': 31,
#          'B.': 27,
#          'Hartsfield': 5,
#          'filed': 6,
#          'suit': 3,
#          'divorce': 2,
#          'his': 246,
#          'wife': 21,
#          'Pearl': 1,
#          'Williams': 11,
#          'His': 24,
#          'petition': 6,
#          'mental': 1,
#          'cruelty': 1,
#          'couple': 10,
#          'married': 7,
#          'Aug.': 5,
#          '1913': 2,
#          'They': 32,
#          'son': 17,
#          'Berry': 3,
#          'daughter': 21,
#          'Mrs.': 229,
#          'J.': 39,
#          'M.': 21,
#          'Cheshire': 1,
#          'Griffin': 2,
#          'Attorneys': 2,
#          'mayor': 2,
#          'amicable': 1,
#          'property': 15,
#          'settlement': 1,
#          'agreed': 12,
#          'upon': 14,
#          'listed': 8,
#          "mayor's": 4,
#          'occupation': 4,
#          'attorney': 17,
#          'age': 7,
#          '71': 1,
#          "wife's": 1,
#          '74': 2,
#          'birth': 5,
#          'Opelika': 1,
#          'Ala.': 6,
#          'lived': 3,
#          'together': 11,
#          'man': 38,
#          'more': 98,
#          'than': 86,
#          'year': 114,
#          'home': 87,
#          '637': 1,
#          'E.': 31,
#          'Pelham': 5,
#          'Rd.': 2,
#          'Aj': 11,
#          'Henry': 13,
#          'L.': 22,
#          'Bowden': 2,
#          'brief': 2,
#          'interlude': 1,
#          'since': 43,
#          '1937': 1,
#          'career': 8,
#          'goes': 2,
#          'back': 51,
#          'council': 18,
#          '1923': 2,
#          'present': 23,
#          'office': 20,
#          'expires': 1,
#          'He': 144,
#          'succeeded': 3,
#          'who': 180,
#          'became': 12,
#          'candidate': 16,
#          'Sept.': 5,
#          '13': 13,
#          'after': 95,
#          'announced': 26,
#          'he': 293,
#          'would': 185,
#          'run': 27,
#          'reelection': 1,
#          'Georgia': 11,
#          'Republicans': 14,
#          'getting': 11,
#          'strong': 7,
#          'encouragement': 1,
#          'enter': 3,
#          '1962': 2,
#          "governor's": 4,
#          'race': 16,
#          'top': 19,
#          'official': 9,
#          'Wednesday': 18,
#          'Robert': 19,
#          'Snodgrass': 1,
#          'GOP': 5,
#          'chairman': 31,
#          'meeting': 28,
#          'held': 26,
#          'Tuesday': 39,
#          'Blue': 9,
#          'Ridge': 3,
#          'brought': 12,
#          'enthusiastic': 1,
#          'responses': 1,
#          'audience': 7,
#          'Party': 9,
#          'Chairman': 4,
#          'James': 32,
#          'W.': 35,
#          'Dorsey': 1,
#          'enthusiasm': 1,
#          'picking': 1,
#          'up': 90,
#          'rally': 3,
#          '8': 17,
#          'Savannah': 1,
#          'newly': 4,
#          'Texas': 43,
#          'Sen.': 16,
#          'John': 48,
#          'Tower': 1,
#          'featured': 3,
#          'speaker': 4,
#          'In': 68,
#          'warned': 2,
#          'entering': 4,
#          'governor': 13,
#          'force': 4,
#          'petitions': 6,
#          'out': 97,
#          'voting': 6,
#          'precincts': 4,
#          'obtain': 6,
#          'signatures': 5,
#          'registered': 2,
#          'Despite': 4,
#          'warning': 3,
#          'unanimous': 2,
#          'vote': 22,
#          'according': 16,
#          'attended': 8,
#          'When': 18,
#          'crowd': 6,
#          'asked': 24,
#          'whether': 11,
#          'wanted': 10,
#          'wait': 2,
#          'make': 33,
#          'voted': 7,
#          '--': 163,
#          'were': 157,
#          'dissents': 1,
#          'largest': 7,
#          'hurdle': 1,
#          'face': 13,
#          'says': 15,
#          'before': 65,
#          'making': 17,
#          'first': 98,
#          'alternative': 4,
#          'courses': 4,
#          'must': 32,
#          'taken': 26,
#          'Five': 4,
#          'per': 43,
#          'cent': 34,
#          'each': 32,
#          'county': 22,
#          'sign': 6,
#          'requesting': 1,
#          'allowed': 5,
#          'names': 3,
#          'candidates': 10,
#          'ballot': 7,
#          'hold': 7,
#          'unit': 10,
#          'system': 18,
#          'party': 28,
#          'opposes': 2,
#          'platform': 2,
#          'Sam': 7,
#          'Caldwell': 2,
#          'Highway': 5,
#          'public': 35,
#          'relations': 11,
#          'director': 24,
#          'resigned': 5,
#          'Lt.': 1,
#          'Gov.': 9,
#          'Garland': 3,
#          "Byrd's": 1,
#          'campaign': 17,
#          "Caldwell's": 1,
#          'resignation': 2,
#          'expected': 33,
#          'time': 53,
#          'Rob': 1,
#          'Ledford': 1,
#          'Gainesville': 1,
#          'assistant': 9,
#          'three': 65,
#          'years': 72,
#          'gubernatorial': 6,
#          'starts': 9,
#          'become': 12,
#          'coordinator': 4,
#          'Byrd': 1,
#          'wind': 3,
#          '1961': 25,
#          'session': 25,
#          'Monday': 49,
#          'head': 18,
#          'where': 37,
#          'highway': 4,
#          'bond': 11,
#          'approved': 8,
#          'shortly': 4,
#          'Before': 5,
#          'adjournment': 2,
#          'afternoon': 14,
#          'Senate': 14,
#          'approve': 2,
#          'study': 12,
#          'allotted': 2,
#          'rural': 9,
#          'urban': 4,
#          'areas': 8,
#          'determine': 2,
#          'what': 45,
#          'adjustments': 2,
#          'made': 76,
#          'Vandiver': 4,
#          'traditional': 2,
#          'visit': 4,
#          'chambers': 2,
#          'toward': 9,
#          'likely': 5,
#          'mention': 4,
#          '$100': 5,
#          'million': 39,
#          'issue': 24,
#          'earlier': 19,
#          'priority': 3,
#          'item': 1,
#          'Construction': 2,
#          'bonds': 10,
#          'Meanwhile': 1,
#          'learned': 6,
#          'very': 16,
#          'near': 10,
#          'being': 34,
#          'ready': 9,
#          '$30': 1,
#          'worth': 11,
#          'reconstruction': 1,
#          'go': 28,
#          'courts': 4,
#          'friendly': 1,
#          'test': 10,
#          'validity': 1,
#          'then': 31,
#          'sales': 51,
#          'begin': 6,
#          'contracts': 4,
#          'let': 5,
#          'repair': 2,
#          'most': 43,
#          'heavily': 3,
#          'traveled': 2,
#          'highways': 2,
#          'A': 95,
#          'source': 5,
#          '$3': 1,
#          '$4': 1,
#          'Rural': 2,
#          'Roads': 2,
#          'Authority': 4,
#          'road': 6,
#          'construction': 14,
#          'revolving': 3,
#          'fund': 10,
#          'department': 12,
#          'apparently': 10,
#          'intends': 1,
#          'issued': 6,
#          'every': 11,
#          'old': 12,
#          'ones': 5,
#          'paid': 13,
#          'off': 48,
#          'tax': 52,
#          'authorities': 4,
#          'opened': 5,
#          '1958': 14,
#          'battle': 7,
#          'against': 56,
#          'issuance': 1,
#          '$50': 2,
#          'roads': 4,
#          'Marvin': 2,
#          'told': 42,
#          'Constitution': 4,
#          'however': 19,
#          'consulted': 2,
#          'yet': 7,
#          'about': 83,
#          'plans': 15,
#          'Schley': 1,
#          'Rep.': 8,
#          'D.': 21,
#          'offer': 6,
#          'resolution': 14,
#          'House': 37,
#          'rescind': 2,
#          "body's": 1,
#          'action': 14,
#          'itself': 4,
#          '$10': 2,
#          'day': 33,
#          'increase': 22,
#          'expense': 7,
#          'allowances': 3,
#          'Sunday': 36,
#          'research': 13,
#          'done': 13,
#          'quickie': 1,
#          'can': 52,
#          'repealed': 1,
#          'outright': 2,
#          'notice': 4,
#          'given': 26,
#          'reconsideration': 2,
#          'sought': 5,
#          'While': 8,
#          'emphasizing': 1,
#          'technical': 5,
#          'details': 3,
#          'fully': 2,
#          'worked': 11,
#          'seek': 9,
#          'set': 30,
#          'aside': 4,
#          'privilege': 2,
#          '87-31': 1,
#          'similar': 11,
#          'passed': 13,
#          '29-5': 1,
#          'As': 13,
#          'word': 5,
#          'offered': 6,
#          'pointed': 8,
#          'last': 115,
#          'November': 6,
#          'rejected': 4,
#          'constitutional': 7,
#          'amendment': 4,
#          'allow': 4,
#          'pay': 27,
#          'raises': 3,
#          'sessions': 4,
#          'veteran': 7,
#          'Jackson': 5,
#          'legislator': 2,
#          'ask': 7,
#          'aid': 23,
#          'education': 13,
#          'something': 7,
#          'consistently': 1,
#          'opposed': 5,
#          'past': 24,
#          'Mac': 1,
#          'Barber': 5,
#          'Commerce': 5,
#          'asking': 4,
#          'endorse': 2,
#          'increased': 4,
#          'support': 11,
#          'provided': 6,
#          'expended': 1,
#          '13th': 1,
#          'members': 41,
#          'congressional': 4,
#          'delegation': 3,
#          'Washington': 34,
#          'like': 26,
#          'see': 17,
#          'But': 54,
#          'congressmen': 3,
#          'specifically': 1,
#          'him': 60,
#          'tossed': 1,
#          'hopper': 1,
#          'formally': 4,
#          'read': 4,
#          'event': 13,
#          'Congress': 11,
#          'does': 14,
#          'Board': 15,
#          'Education': 13,
#          'directed': 8,
#          'give': 22,
#          'teacher': 7,
#          'Colquitt': 2,
#          'After': 14,
#          'long': 22,
#          'hot': 9,
#          'controversy': 5,
#          'Miller': 2,
#          'school': 42,
#          'superintendent': 9,
#          'policeman': 2,
#          'put': 13,
#          'coolest': 2,
#          'I': 97,
#          'ever': 13,
#          'saw': 9,
#          'Harry': 7,
#          'Davis': 13,
#          'agriculture': 2,
#          'defeated': 3,
#          'Felix': 2,
#          'Bush': 3,
#          'principal': 5,
#          'Democratic': 30,
#          '1,119': 1,
#          'votes': 4,
#          "Saturday's": 2,
#          'got': 23,
#          '402': 1,
#          'Ordinary': 2,
#          'Carey': 5,
#          'armed': 4,
#          'pistol': 2,
#          'stood': 4,
#          'polls': 3,
#          'insure': 1,
#          'order': 10,
#          'calmest': 1,
#          'Policeman': 1,
#          'Tom': 5,
#          'Being': 1,
#          'just': 30,
#          'church': 12,
#          "didn't": 7,
#          'smell': 1,
#          'drop': 4,
#          'liquor': 4,
#          'bit': 5,
#          'trouble': 7,
#          'leading': 5,
#          'quiet': 4,
#          'marked': 2,
#          'anonymous': 4,
#          'midnight': 4,
#          'phone': 2,
#          'calls': 13,
#          'veiled': 2,
#          'threats': 1,
#          'violence': 1,
#          'former': 24,
#          'George': 14,
#          'P.': 13,
#          'Callan': 1,
#          'shot': 9,
#          'himself': 9,
#          'death': 8,
#          'March': 28,
#          '18': 14,
#          'four': 44,
#          'days': 32,
#          'post': 10,
#          'dispute': 2,
#          'board': 41,
#          'During': 2,
#          'reportedly': 3,
#          'telephone': 6,
#          'too': 15,
#          'subjected': 2,
#          'soon': 13,
#          'scheduled': 12,
#          'Many': 6,
#          'local': 29,
#          'feared': 1,
#          'carry': 8,
#          'gun': 2,
#          'promised': 4,
#          'Sheriff': 2,
#          'Tabb': 1,
#          'ordinary': 2,
#          'good': 27,
#          'promise': 1,
#          'Everything': 1,
#          'went': 19,
#          'real': 11,
#          'smooth': 1,
#          'sheriff': 3,
#          'There': 28,
#          "wasn't": 3,
#          'Austin': 12,
#          'approval': 6,
#          'Price': 2,
#          "Daniel's": 1,
#          'abandoned': 3,
#          'seemed': 5,
#          'certain': 7,
#          'Thursday': 13,
#          'despite': 6,
#          'adamant': 1,
#          'protests': 1,
#          'bankers': 7,
#          'Daniel': 4,
#          'personally': 3,
#          'led': 11,
#          'fight': 9,
#          'measure': 11,
#          'watered': 1,
#          'down': 36,
#          'considerably': 2,
#          'rejection': 2,
#          'Legislatures': 1,
#          'hearing': 14,
#          'Revenue': 5,
#          'Taxation': 1,
#          'Under': 6,
#          'rules': 9,
#          'automatically': 1,
#          'subcommittee': 1,
#          'week': 45,
#          'questions': 5,
#          'taunted': 1,
#          'appearing': 1,
#          'witnesses': 7,
#          'left': 30,
#          'little': 16,
#          'doubt': 4,
#          'recommend': 4,
#          'passage': 1,
#          'termed': 4,
#          'extremely': 1,
#          'conservative': 2,
#          'estimate': 3,
#          'produce': 5,
#          '17': 13,
#          'dollars': 12,
#          'help': 20,
#          'erase': 1,
#          'anticipated': 4,
#          'deficit': 1,
#          '63': 1,
#          'current': 9,
#          'fiscal': 5,
#          '31': 4,
#          'merely': 7,
#          'means': 13,
#          'enforcing': 1,
#          'escheat': 2,
#          'books': 6,
#          'republic': 1,
#          'permits': 3,
#          'over': 82,
#          'bank': 11,
#          'accounts': 2,
#          'stocks': 9,
#          'personal': 6,
#          'persons': 20,
#          'missing': 2,
#          'seven': 12,
#          'bill': 39,
#          'drafted': 1,
#          'banks': 4,
#          'insurance': 4,
#          'firms': 13,
#          'pipeline': 2,
#          'companies': 14,
#          'corporations': 2,
#          'report': 15,
#          'treasurer': 5,
#          'cannot': 9,
#          'enforced': 3,
#          'now': 48,
#          'because': 35,
#          'almost': 17,
#          'impossible': 3,
#          'locate': 1,
#          'declared': 12,
#          'Dewey': 1,
#          'Lawrence': 9,
#          'Tyler': 2,
#          'lawyer': 7,
#          'representing': 4,
#          'Bankers': 3,
#          'sounded': 1,
#          'opposition': 7,
#          'keynote': 1,
#          'violate': 2,
#          'their': 133,
#          'contractual': 1,
#          'obligations': 4,
#          'depositors': 1,
#          'undermine': 1,
#          'confidence': 5,
#          'customers': 6,
#          'If': 13,
#          'you': 22,
#          'destroy': 4,
#          'economy': 8,
#          'You': 8,
#          'circulation': 2,
#          'millions': 8,
#          'Charles': 20,
#          'Hughes': 22,
#          'Sherman': 6,
#          'sponsor': 3,
#          'failure': 4,
#          'enact': 1,
#          'amount': 17,
#          'gift': 3,
#          "taxpayers'": 2,
#          'pockets': 2,
#          'contention': 2,
#          'denied': 5,
#          'several': 29,
#          'including': 14,
#          'Scott': 3,
#          'Hudson': 2,
#          'Gaynor': 1,
#          'Jones': 20,
#          'Houston': 13,
#          'Brady': 1,
#          'Harlingen': 1,
#          'Howard': 10,
#          'Cox': 3,
#          'argued': 5,
#          'probably': 14,
#          'unconstitutional': 1,
#          'impair': 1,
#          'complained': 3,
#          'enough': 10,
#          'introduced': 7,
#          'only': 70,
#          'Senators': 1,
#          'unanimously': 2,
#          'Parkhouse': 5,
#          'Dallas': 45,
#          'authorizing': 2,
#          'schools': 26,
#          'deaf': 5,
#          'designed': 12,
#          'special': 31,
#          'schooling': 2,
#          ...})

# %% [markdown]
# ### 3.2 Create skipgrams

# %%
def create_skipgrams(corpus, window_size=1):
    skipgrams = []
    for sentence in corpus:
        sentence_length = len(sentence)
        for i in range(1, sentence_length-1): 
            center_word = sentence[i]
            outside_word = []
            for ws in range(window_size):
                ### check if it is outside of range of the list
                if i + 1 + ws < sentence_length:
                    outside_word.append(sentence[i+ws+1])
                if i - ws - 1 >= 0:
                    outside_word.append(sentence[(i - ws - 1)])
            for o in outside_word:
                skipgrams.append(((center_word, o)))
    return skipgrams

# %%
skipgrams = create_skipgrams(corpus_tokenized,2)

# %%
skipgrams
# Out:
# [('Fulton', 'County'),
#  ('Fulton', 'The'),
#  ('Fulton', 'Grand'),
#  ('County', 'Grand'),
#  ('County', 'Fulton'),
#  ('County', 'Jury'),
#  ('County', 'The'),
#  ('Grand', 'Jury'),
#  ('Grand', 'County'),
#  ('Grand', 'said'),
#  ('Grand', 'Fulton'),
#  ('Jury', 'said'),
#  ('Jury', 'Grand'),
#  ('Jury', 'Friday'),
#  ('Jury', 'County'),
#  ('said', 'Friday'),
#  ('said', 'Jury'),
#  ('said', 'an'),
#  ('said', 'Grand'),
#  ('Friday', 'an'),
#  ('Friday', 'said'),
#  ('Friday', 'investigation'),
#  ('Friday', 'Jury'),
#  ('an', 'investigation'),
#  ('an', 'Friday'),
#  ('an', 'of'),
#  ('an', 'said'),
#  ('investigation', 'of'),
#  ('investigation', 'an'),
#  ('investigation', "Atlanta's"),
#  ('investigation', 'Friday'),
#  ('of', "Atlanta's"),
#  ('of', 'investigation'),
#  ('of', 'recent'),
#  ('of', 'an'),
#  ("Atlanta's", 'recent'),
#  ("Atlanta's", 'of'),
#  ("Atlanta's", 'primary'),
#  ("Atlanta's", 'investigation'),
#  ('recent', 'primary'),
#  ('recent', "Atlanta's"),
#  ('recent', 'election'),
#  ('recent', 'of'),
#  ('primary', 'election'),
#  ('primary', 'recent'),
#  ('primary', 'produced'),
#  ('primary', "Atlanta's"),
#  ('election', 'produced'),
#  ('election', 'primary'),
#  ('election', '``'),
#  ('election', 'recent'),
#  ('produced', '``'),
#  ('produced', 'election'),
#  ('produced', 'no'),
#  ('produced', 'primary'),
#  ('``', 'no'),
#  ('``', 'produced'),
#  ('``', 'evidence'),
#  ('``', 'election'),
#  ('no', 'evidence'),
#  ('no', '``'),
#  ('no', "''"),
#  ('no', 'produced'),
#  ('evidence', "''"),
#  ('evidence', 'no'),
#  ('evidence', 'that'),
#  ('evidence', '``'),
#  ("''", 'that'),
#  ("''", 'evidence'),
#  ("''", 'any'),
#  ("''", 'no'),
#  ('that', 'any'),
#  ('that', "''"),
#  ('that', 'irregularities'),
#  ('that', 'evidence'),
#  ('any', 'irregularities'),
#  ('any', 'that'),
#  ('any', 'took'),
#  ('any', "''"),
#  ('irregularities', 'took'),
#  ('irregularities', 'any'),
#  ('irregularities', 'place'),
#  ('irregularities', 'that'),
#  ('took', 'place'),
#  ('took', 'irregularities'),
#  ('took', '.'),
#  ('took', 'any'),
#  ('place', '.'),
#  ('place', 'took'),
#  ('place', 'irregularities'),
#  ('jury', 'further'),
#  ('jury', 'The'),
#  ('jury', 'said'),
#  ('further', 'said'),
#  ('further', 'jury'),
#  ('further', 'in'),
#  ('further', 'The'),
#  ('said', 'in'),
#  ('said', 'further'),
#  ('said', 'term-end'),
#  ('said', 'jury'),
#  ('in', 'term-end'),
#  ('in', 'said'),
#  ('in', 'presentments'),
#  ('in', 'further'),
#  ('term-end', 'presentments'),
#  ('term-end', 'in'),
#  ('term-end', 'that'),
#  ('term-end', 'said'),
#  ('presentments', 'that'),
#  ('presentments', 'term-end'),
#  ('presentments', 'the'),
#  ('presentments', 'in'),
#  ('that', 'the'),
#  ('that', 'presentments'),
#  ('that', 'City'),
#  ('that', 'term-end'),
#  ('the', 'City'),
#  ('the', 'that'),
#  ('the', 'Executive'),
#  ('the', 'presentments'),
#  ('City', 'Executive'),
#  ('City', 'the'),
#  ('City', 'Committee'),
#  ('City', 'that'),
#  ('Executive', 'Committee'),
#  ('Executive', 'City'),
#  ('Executive', ','),
#  ('Executive', 'the'),
#  ('Committee', ','),
#  ('Committee', 'Executive'),
#  ('Committee', 'which'),
#  ('Committee', 'City'),
#  (',', 'which'),
#  (',', 'Committee'),
#  (',', 'had'),
#  (',', 'Executive'),
#  ('which', 'had'),
#  ('which', ','),
#  ('which', 'over-all'),
#  ('which', 'Committee'),
#  ('had', 'over-all'),
#  ('had', 'which'),
#  ('had', 'charge'),
#  ('had', ','),
#  ('over-all', 'charge'),
#  ('over-all', 'had'),
#  ('over-all', 'of'),
#  ('over-all', 'which'),
#  ('charge', 'of'),
#  ('charge', 'over-all'),
#  ('charge', 'the'),
#  ('charge', 'had'),
#  ('of', 'the'),
#  ('of', 'charge'),
#  ('of', 'election'),
#  ('of', 'over-all'),
#  ('the', 'election'),
#  ('the', 'of'),
#  ('the', ','),
#  ('the', 'charge'),
#  ('election', ','),
#  ('election', 'the'),
#  ('election', '``'),
#  ('election', 'of'),
#  (',', '``'),
#  (',', 'election'),
#  (',', 'deserves'),
#  (',', 'the'),
#  ('``', 'deserves'),
#  ('``', ','),
#  ('``', 'the'),
#  ('``', 'election'),
#  ('deserves', 'the'),
#  ('deserves', '``'),
#  ('deserves', 'praise'),
#  ('deserves', ','),
#  ('the', 'praise'),
#  ('the', 'deserves'),
#  ('the', 'and'),
#  ('the', '``'),
#  ('praise', 'and'),
#  ('praise', 'the'),
#  ('praise', 'thanks'),
#  ('praise', 'deserves'),
#  ('and', 'thanks'),
#  ('and', 'praise'),
#  ('and', 'of'),
#  ('and', 'the'),
#  ('thanks', 'of'),
#  ('thanks', 'and'),
#  ('thanks', 'the'),
#  ('thanks', 'praise'),
#  ('of', 'the'),
#  ('of', 'thanks'),
#  ('of', 'City'),
#  ('of', 'and'),
#  ('the', 'City'),
#  ('the', 'of'),
#  ('the', 'of'),
#  ('the', 'thanks'),
#  ('City', 'of'),
#  ('City', 'the'),
#  ('City', 'Atlanta'),
#  ('City', 'of'),
#  ('of', 'Atlanta'),
#  ('of', 'City'),
#  ('of', "''"),
#  ('of', 'the'),
#  ('Atlanta', "''"),
#  ('Atlanta', 'of'),
#  ('Atlanta', 'for'),
#  ('Atlanta', 'City'),
#  ("''", 'for'),
#  ("''", 'Atlanta'),
#  ("''", 'the'),
#  ("''", 'of'),
#  ('for', 'the'),
#  ('for', "''"),
#  ('for', 'manner'),
#  ('for', 'Atlanta'),
#  ('the', 'manner'),
#  ('the', 'for'),
#  ('the', 'in'),
#  ('the', "''"),
#  ('manner', 'in'),
#  ('manner', 'the'),
#  ('manner', 'which'),
#  ('manner', 'for'),
#  ('in', 'which'),
#  ('in', 'manner'),
#  ('in', 'the'),
#  ('in', 'the'),
#  ('which', 'the'),
#  ('which', 'in'),
#  ('which', 'election'),
#  ('which', 'manner'),
#  ('the', 'election'),
#  ('the', 'which'),
#  ('the', 'was'),
#  ('the', 'in'),
#  ('election', 'was'),
#  ('election', 'the'),
#  ('election', 'conducted'),
#  ('election', 'which'),
#  ('was', 'conducted'),
#  ('was', 'election'),
#  ('was', '.'),
#  ('was', 'the'),
#  ('conducted', '.'),
#  ('conducted', 'was'),
#  ('conducted', 'election'),
#  ('September-October', 'term'),
#  ('September-October', 'The'),
#  ('September-October', 'jury'),
#  ('term', 'jury'),
#  ('term', 'September-October'),
#  ('term', 'had'),
#  ('term', 'The'),
#  ('jury', 'had'),
#  ('jury', 'term'),
#  ('jury', 'been'),
#  ('jury', 'September-October'),
#  ('had', 'been'),
#  ('had', 'jury'),
#  ('had', 'charged'),
#  ('had', 'term'),
#  ('been', 'charged'),
#  ('been', 'had'),
#  ('been', 'by'),
#  ('been', 'jury'),
#  ('charged', 'by'),
#  ('charged', 'been'),
#  ('charged', 'Fulton'),
#  ('charged', 'had'),
#  ('by', 'Fulton'),
#  ('by', 'charged'),
#  ('by', 'Superior'),
#  ('by', 'been'),
#  ('Fulton', 'Superior'),
#  ('Fulton', 'by'),
#  ('Fulton', 'Court'),
#  ('Fulton', 'charged'),
#  ('Superior', 'Court'),
#  ('Superior', 'Fulton'),
#  ('Superior', 'Judge'),
#  ('Superior', 'by'),
#  ('Court', 'Judge'),
#  ('Court', 'Superior'),
#  ('Court', 'Durwood'),
#  ('Court', 'Fulton'),
#  ('Judge', 'Durwood'),
#  ('Judge', 'Court'),
#  ('Judge', 'Pye'),
#  ('Judge', 'Superior'),
#  ('Durwood', 'Pye'),
#  ('Durwood', 'Judge'),
#  ('Durwood', 'to'),
#  ('Durwood', 'Court'),
#  ('Pye', 'to'),
#  ('Pye', 'Durwood'),
#  ('Pye', 'investigate'),
#  ('Pye', 'Judge'),
#  ('to', 'investigate'),
#  ('to', 'Pye'),
#  ('to', 'reports'),
#  ('to', 'Durwood'),
#  ('investigate', 'reports'),
#  ('investigate', 'to'),
#  ('investigate', 'of'),
#  ('investigate', 'Pye'),
#  ('reports', 'of'),
#  ('reports', 'investigate'),
#  ('reports', 'possible'),
#  ('reports', 'to'),
#  ('of', 'possible'),
#  ('of', 'reports'),
#  ('of', '``'),
#  ('of', 'investigate'),
#  ('possible', '``'),
#  ('possible', 'of'),
#  ('possible', 'irregularities'),
#  ('possible', 'reports'),
#  ('``', 'irregularities'),
#  ('``', 'possible'),
#  ('``', "''"),
#  ('``', 'of'),
#  ('irregularities', "''"),
#  ('irregularities', '``'),
#  ('irregularities', 'in'),
#  ('irregularities', 'possible'),
#  ("''", 'in'),
#  ("''", 'irregularities'),
#  ("''", 'the'),
#  ("''", '``'),
#  ('in', 'the'),
#  ('in', "''"),
#  ('in', 'hard-fought'),
#  ('in', 'irregularities'),
#  ('the', 'hard-fought'),
#  ('the', 'in'),
#  ('the', 'primary'),
#  ('the', "''"),
#  ('hard-fought', 'primary'),
#  ('hard-fought', 'the'),
#  ('hard-fought', 'which'),
#  ('hard-fought', 'in'),
#  ('primary', 'which'),
#  ('primary', 'hard-fought'),
#  ('primary', 'was'),
#  ('primary', 'the'),
#  ('which', 'was'),
#  ('which', 'primary'),
#  ('which', 'won'),
#  ('which', 'hard-fought'),
#  ('was', 'won'),
#  ('was', 'which'),
#  ('was', 'by'),
#  ('was', 'primary'),
#  ('won', 'by'),
#  ('won', 'was'),
#  ('won', 'Mayor-nominate'),
#  ('won', 'which'),
#  ('by', 'Mayor-nominate'),
#  ('by', 'won'),
#  ('by', 'Ivan'),
#  ('by', 'was'),
#  ('Mayor-nominate', 'Ivan'),
#  ('Mayor-nominate', 'by'),
#  ('Mayor-nominate', 'Allen'),
#  ('Mayor-nominate', 'won'),
#  ('Ivan', 'Allen'),
#  ('Ivan', 'Mayor-nominate'),
#  ('Ivan', 'Jr.'),
#  ('Ivan', 'by'),
#  ('Allen', 'Jr.'),
#  ('Allen', 'Ivan'),
#  ('Allen', '.'),
#  ('Allen', 'Mayor-nominate'),
#  ('Jr.', '.'),
#  ('Jr.', 'Allen'),
#  ('Jr.', 'Ivan'),
#  ('Only', 'a'),
#  ('Only', '``'),
#  ('Only', 'relative'),
#  ('a', 'relative'),
#  ('a', 'Only'),
#  ('a', 'handful'),
#  ('a', '``'),
#  ('relative', 'handful'),
#  ('relative', 'a'),
#  ('relative', 'of'),
#  ('relative', 'Only'),
#  ('handful', 'of'),
#  ('handful', 'relative'),
#  ('handful', 'such'),
#  ('handful', 'a'),
#  ('of', 'such'),
#  ('of', 'handful'),
#  ('of', 'reports'),
#  ('of', 'relative'),
#  ('such', 'reports'),
#  ('such', 'of'),
#  ('such', 'was'),
#  ('such', 'handful'),
#  ('reports', 'was'),
#  ('reports', 'such'),
#  ('reports', 'received'),
#  ('reports', 'of'),
#  ('was', 'received'),
#  ('was', 'reports'),
#  ('was', "''"),
#  ('was', 'such'),
#  ('received', "''"),
#  ('received', 'was'),
#  ('received', ','),
#  ('received', 'reports'),
#  ("''", ','),
#  ("''", 'received'),
#  ("''", 'the'),
#  ("''", 'was'),
#  (',', 'the'),
#  (',', "''"),
#  (',', 'jury'),
#  (',', 'received'),
#  ('the', 'jury'),
#  ('the', ','),
#  ('the', 'said'),
#  ('the', "''"),
#  ('jury', 'said'),
#  ('jury', 'the'),
#  ('jury', ','),
#  ('jury', ','),
#  ('said', ','),
#  ('said', 'jury'),
#  ('said', '``'),
#  ('said', 'the'),
#  (',', '``'),
#  (',', 'said'),
#  (',', 'considering'),
#  (',', 'jury'),
#  ('``', 'considering'),
#  ('``', ','),
#  ('``', 'the'),
#  ('``', 'said'),
#  ('considering', 'the'),
#  ('considering', '``'),
#  ('considering', 'widespread'),
#  ('considering', ','),
#  ('the', 'widespread'),
#  ('the', 'considering'),
#  ('the', 'interest'),
#  ('the', '``'),
#  ('widespread', 'interest'),
#  ('widespread', 'the'),
#  ('widespread', 'in'),
#  ('widespread', 'considering'),
#  ('interest', 'in'),
#  ('interest', 'widespread'),
#  ('interest', 'the'),
#  ('interest', 'the'),
#  ('in', 'the'),
#  ('in', 'interest'),
#  ('in', 'election'),
#  ('in', 'widespread'),
#  ('the', 'election'),
#  ('the', 'in'),
#  ('the', ','),
#  ('the', 'interest'),
#  ('election', ','),
#  ('election', 'the'),
#  ('election', 'the'),
#  ('election', 'in'),
#  (',', 'the'),
#  (',', 'election'),
#  (',', 'number'),
#  (',', 'the'),
#  ('the', 'number'),
#  ('the', ','),
#  ('the', 'of'),
#  ('the', 'election'),
#  ('number', 'of'),
#  ('number', 'the'),
#  ('number', 'voters'),
#  ('number', ','),
#  ('of', 'voters'),
#  ('of', 'number'),
#  ('of', 'and'),
#  ('of', 'the'),
#  ('voters', 'and'),
#  ('voters', 'of'),
#  ('voters', 'the'),
#  ('voters', 'number'),
#  ('and', 'the'),
#  ('and', 'voters'),
#  ('and', 'size'),
#  ('and', 'of'),
#  ('the', 'size'),
#  ('the', 'and'),
#  ('the', 'of'),
#  ('the', 'voters'),
#  ('size', 'of'),
#  ('size', 'the'),
#  ('size', 'this'),
#  ('size', 'and'),
#  ('of', 'this'),
#  ('of', 'size'),
#  ('of', 'city'),
#  ('of', 'the'),
#  ('this', 'city'),
#  ('this', 'of'),
#  ('this', "''"),
#  ('this', 'size'),
#  ('city', "''"),
#  ('city', 'this'),
#  ('city', '.'),
#  ('city', 'of'),
#  ("''", '.'),
#  ("''", 'city'),
#  ("''", 'this'),
#  ('jury', 'said'),
#  ('jury', 'The'),
#  ('jury', 'it'),
#  ('said', 'it'),
#  ('said', 'jury'),
#  ('said', 'did'),
#  ('said', 'The'),
#  ('it', 'did'),
#  ('it', 'said'),
#  ('it', 'find'),
#  ('it', 'jury'),
#  ('did', 'find'),
#  ('did', 'it'),
#  ('did', 'that'),
#  ('did', 'said'),
#  ('find', 'that'),
#  ('find', 'did'),
#  ('find', 'many'),
#  ('find', 'it'),
#  ('that', 'many'),
#  ('that', 'find'),
#  ('that', 'of'),
#  ('that', 'did'),
#  ('many', 'of'),
#  ('many', 'that'),
#  ('many', "Georgia's"),
#  ('many', 'find'),
#  ('of', "Georgia's"),
#  ('of', 'many'),
#  ('of', 'registration'),
#  ('of', 'that'),
#  ("Georgia's", 'registration'),
#  ("Georgia's", 'of'),
#  ("Georgia's", 'and'),
#  ("Georgia's", 'many'),
#  ('registration', 'and'),
#  ('registration', "Georgia's"),
#  ('registration', 'election'),
#  ('registration', 'of'),
#  ('and', 'election'),
#  ('and', 'registration'),
#  ('and', 'laws'),
#  ('and', "Georgia's"),
#  ('election', 'laws'),
#  ('election', 'and'),
#  ('election', '``'),
#  ('election', 'registration'),
#  ('laws', '``'),
#  ('laws', 'election'),
#  ('laws', 'are'),
#  ('laws', 'and'),
#  ('``', 'are'),
#  ('``', 'laws'),
#  ('``', 'outmoded'),
#  ('``', 'election'),
#  ('are', 'outmoded'),
#  ('are', '``'),
#  ('are', 'or'),
#  ('are', 'laws'),
#  ('outmoded', 'or'),
#  ('outmoded', 'are'),
#  ('outmoded', 'inadequate'),
#  ('outmoded', '``'),
#  ('or', 'inadequate'),
#  ('or', 'outmoded'),
#  ('or', 'and'),
#  ('or', 'are'),
#  ('inadequate', 'and'),
#  ('inadequate', 'or'),
#  ('inadequate', 'often'),
#  ('inadequate', 'outmoded'),
#  ('and', 'often'),
#  ('and', 'inadequate'),
#  ('and', 'ambiguous'),
#  ('and', 'or'),
#  ('often', 'ambiguous'),
#  ('often', 'and'),
#  ('often', "''"),
#  ('often', 'inadequate'),
#  ('ambiguous', "''"),
#  ('ambiguous', 'often'),
#  ('ambiguous', '.'),
#  ('ambiguous', 'and'),
#  ("''", '.'),
#  ("''", 'ambiguous'),
#  ("''", 'often'),
#  ('recommended', 'that'),
#  ('recommended', 'It'),
#  ('recommended', 'Fulton'),
#  ('that', 'Fulton'),
#  ('that', 'recommended'),
#  ('that', 'legislators'),
#  ('that', 'It'),
#  ('Fulton', 'legislators'),
#  ('Fulton', 'that'),
#  ('Fulton', 'act'),
#  ('Fulton', 'recommended'),
#  ('legislators', 'act'),
#  ('legislators', 'Fulton'),
#  ('legislators', '``'),
#  ('legislators', 'that'),
#  ('act', '``'),
#  ('act', 'legislators'),
#  ('act', 'to'),
#  ('act', 'Fulton'),
#  ('``', 'to'),
#  ('``', 'act'),
#  ('``', 'have'),
#  ('``', 'legislators'),
#  ('to', 'have'),
#  ('to', '``'),
#  ('to', 'these'),
#  ('to', 'act'),
#  ('have', 'these'),
#  ('have', 'to'),
#  ('have', 'laws'),
#  ('have', '``'),
#  ('these', 'laws'),
#  ('these', 'have'),
#  ('these', 'studied'),
#  ('these', 'to'),
#  ('laws', 'studied'),
#  ('laws', 'these'),
#  ('laws', 'and'),
#  ('laws', 'have'),
#  ('studied', 'and'),
#  ('studied', 'laws'),
#  ('studied', 'revised'),
#  ('studied', 'these'),
#  ('and', 'revised'),
#  ('and', 'studied'),
#  ('and', 'to'),
#  ('and', 'laws'),
#  ('revised', 'to'),
#  ('revised', 'and'),
#  ('revised', 'the'),
#  ('revised', 'studied'),
#  ('to', 'the'),
#  ('to', 'revised'),
#  ('to', 'end'),
#  ('to', 'and'),
#  ('the', 'end'),
#  ('the', 'to'),
#  ('the', 'of'),
#  ('the', 'revised'),
#  ('end', 'of'),
#  ('end', 'the'),
#  ('end', 'modernizing'),
#  ('end', 'to'),
#  ('of', 'modernizing'),
#  ('of', 'end'),
#  ('of', 'and'),
#  ('of', 'the'),
#  ('modernizing', 'and'),
#  ('modernizing', 'of'),
#  ('modernizing', 'improving'),
#  ('modernizing', 'end'),
#  ('and', 'improving'),
#  ('and', 'modernizing'),
#  ('and', 'them'),
#  ('and', 'of'),
#  ('improving', 'them'),
#  ('improving', 'and'),
#  ('improving', "''"),
#  ('improving', 'modernizing'),
#  ('them', "''"),
#  ('them', 'improving'),
#  ('them', '.'),
#  ('them', 'and'),
#  ("''", '.'),
#  ("''", 'them'),
#  ("''", 'improving'),
#  ('grand', 'jury'),
#  ('grand', 'The'),
#  ('grand', 'commented'),
#  ('jury', 'commented'),
#  ('jury', 'grand'),
#  ('jury', 'on'),
#  ('jury', 'The'),
#  ('commented', 'on'),
#  ('commented', 'jury'),
#  ('commented', 'a'),
#  ('commented', 'grand'),
#  ('on', 'a'),
#  ('on', 'commented'),
#  ('on', 'number'),
#  ('on', 'jury'),
#  ('a', 'number'),
#  ('a', 'on'),
#  ('a', 'of'),
#  ('a', 'commented'),
#  ('number', 'of'),
#  ('number', 'a'),
#  ('number', 'other'),
#  ('number', 'on'),
#  ('of', 'other'),
#  ('of', 'number'),
#  ('of', 'topics'),
#  ('of', 'a'),
#  ('other', 'topics'),
#  ('other', 'of'),
#  ('other', ','),
#  ('other', 'number'),
#  ('topics', ','),
#  ('topics', 'other'),
#  ('topics', 'among'),
#  ('topics', 'of'),
#  (',', 'among'),
#  (',', 'topics'),
#  (',', 'them'),
#  (',', 'other'),
#  ('among', 'them'),
#  ('among', ','),
#  ('among', 'the'),
#  ('among', 'topics'),
#  ('them', 'the'),
#  ('them', 'among'),
#  ('them', 'Atlanta'),
#  ('them', ','),
#  ('the', 'Atlanta'),
#  ('the', 'them'),
#  ('the', 'and'),
#  ('the', 'among'),
#  ('Atlanta', 'and'),
#  ('Atlanta', 'the'),
#  ('Atlanta', 'Fulton'),
#  ('Atlanta', 'them'),
#  ('and', 'Fulton'),
#  ('and', 'Atlanta'),
#  ('and', 'County'),
#  ('and', 'the'),
#  ('Fulton', 'County'),
#  ('Fulton', 'and'),
#  ('Fulton', 'purchasing'),
#  ('Fulton', 'Atlanta'),
#  ('County', 'purchasing'),
#  ('County', 'Fulton'),
#  ('County', 'departments'),
#  ('County', 'and'),
#  ('purchasing', 'departments'),
#  ('purchasing', 'County'),
#  ('purchasing', 'which'),
#  ('purchasing', 'Fulton'),
#  ('departments', 'which'),
#  ('departments', 'purchasing'),
#  ('departments', 'it'),
#  ('departments', 'County'),
#  ('which', 'it'),
#  ('which', 'departments'),
#  ('which', 'said'),
#  ('which', 'purchasing'),
#  ('it', 'said'),
#  ('it', 'which'),
#  ('it', '``'),
#  ('it', 'departments'),
#  ('said', '``'),
#  ('said', 'it'),
#  ('said', 'are'),
#  ('said', 'which'),
#  ('``', 'are'),
#  ('``', 'said'),
#  ('``', 'well'),
#  ('``', 'it'),
#  ('are', 'well'),
#  ('are', '``'),
#  ('are', 'operated'),
#  ('are', 'said'),
#  ('well', 'operated'),
#  ('well', 'are'),
#  ('well', 'and'),
#  ('well', '``'),
#  ('operated', 'and'),
#  ('operated', 'well'),
#  ('operated', 'follow'),
#  ('operated', 'are'),
#  ('and', 'follow'),
#  ('and', 'operated'),
#  ('and', 'generally'),
#  ('and', 'well'),
#  ('follow', 'generally'),
#  ('follow', 'and'),
#  ('follow', 'accepted'),
#  ('follow', 'operated'),
#  ('generally', 'accepted'),
#  ('generally', 'follow'),
#  ('generally', 'practices'),
#  ('generally', 'and'),
#  ('accepted', 'practices'),
#  ('accepted', 'generally'),
#  ('accepted', 'which'),
#  ('accepted', 'follow'),
#  ('practices', 'which'),
#  ('practices', 'accepted'),
#  ('practices', 'inure'),
#  ('practices', 'generally'),
#  ('which', 'inure'),
#  ('which', 'practices'),
#  ('which', 'to'),
#  ('which', 'accepted'),
#  ('inure', 'to'),
#  ('inure', 'which'),
#  ('inure', 'the'),
#  ('inure', 'practices'),
#  ('to', 'the'),
#  ('to', 'inure'),
#  ('to', 'best'),
#  ('to', 'which'),
#  ('the', 'best'),
#  ('the', 'to'),
#  ('the', 'interest'),
#  ('the', 'inure'),
#  ('best', 'interest'),
#  ('best', 'the'),
#  ('best', 'of'),
#  ('best', 'to'),
#  ('interest', 'of'),
#  ('interest', 'best'),
#  ('interest', 'both'),
#  ('interest', 'the'),
#  ('of', 'both'),
#  ('of', 'interest'),
#  ('of', 'governments'),
#  ('of', 'best'),
#  ('both', 'governments'),
#  ('both', 'of'),
#  ('both', "''"),
#  ('both', 'interest'),
#  ('governments', "''"),
#  ('governments', 'both'),
#  ('governments', '.'),
#  ('governments', 'of'),
#  ("''", '.'),
#  ("''", 'governments'),
#  ("''", 'both'),
#  (',', 'the'),
#  (',', 'However'),
#  (',', 'jury'),
#  ('the', 'jury'),
#  ('the', ','),
#  ('the', 'said'),
#  ('the', 'However'),
#  ('jury', 'said'),
#  ('jury', 'the'),
#  ('jury', 'it'),
#  ('jury', ','),
#  ('said', 'it'),
#  ('said', 'jury'),
#  ('said', 'believes'),
#  ('said', 'the'),
#  ('it', 'believes'),
#  ('it', 'said'),
#  ('it', '``'),
#  ('it', 'jury'),
#  ('believes', '``'),
#  ('believes', 'it'),
#  ('believes', 'these'),
#  ('believes', 'said'),
#  ('``', 'these'),
#  ('``', 'believes'),
#  ('``', 'two'),
#  ('``', 'it'),
#  ('these', 'two'),
#  ('these', '``'),
#  ('these', 'offices'),
#  ('these', 'believes'),
#  ('two', 'offices'),
#  ('two', 'these'),
#  ('two', 'should'),
#  ('two', '``'),
#  ('offices', 'should'),
#  ('offices', 'two'),
#  ('offices', 'be'),
#  ('offices', 'these'),
#  ('should', 'be'),
#  ('should', 'offices'),
#  ('should', 'combined'),
#  ('should', 'two'),
#  ('be', 'combined'),
#  ('be', 'should'),
#  ('be', 'to'),
#  ('be', 'offices'),
#  ('combined', 'to'),
#  ('combined', 'be'),
#  ('combined', 'achieve'),
#  ('combined', 'should'),
#  ('to', 'achieve'),
#  ('to', 'combined'),
#  ('to', 'greater'),
#  ('to', 'be'),
#  ('achieve', 'greater'),
#  ('achieve', 'to'),
#  ('achieve', 'efficiency'),
#  ('achieve', 'combined'),
#  ('greater', 'efficiency'),
#  ('greater', 'achieve'),
#  ('greater', 'and'),
#  ('greater', 'to'),
#  ('efficiency', 'and'),
#  ('efficiency', 'greater'),
#  ('efficiency', 'reduce'),
#  ('efficiency', 'achieve'),
#  ('and', 'reduce'),
#  ('and', 'efficiency'),
#  ('and', 'the'),
#  ('and', 'greater'),
#  ('reduce', 'the'),
#  ('reduce', 'and'),
#  ('reduce', 'cost'),
#  ('reduce', 'efficiency'),
#  ('the', 'cost'),
#  ('the', 'reduce'),
#  ('the', 'of'),
#  ('the', 'and'),
#  ('cost', 'of'),
#  ('cost', 'the'),
#  ('cost', 'administration'),
#  ('cost', 'reduce'),
#  ('of', 'administration'),
#  ('of', 'cost'),
#  ('of', "''"),
#  ('of', 'the'),
#  ('administration', "''"),
#  ('administration', 'of'),
#  ('administration', '.'),
#  ('administration', 'cost'),
#  ("''", '.'),
#  ("''", 'administration'),
#  ("''", 'of'),
#  ('City', 'Purchasing'),
#  ('City', 'The'),
#  ('City', 'Department'),
#  ('Purchasing', 'Department'),
#  ('Purchasing', 'City'),
#  ('Purchasing', ','),
#  ('Purchasing', 'The'),
#  ('Department', ','),
#  ('Department', 'Purchasing'),
#  ('Department', 'the'),
#  ('Department', 'City'),
#  (',', 'the'),
#  (',', 'Department'),
#  (',', 'jury'),
#  (',', 'Purchasing'),
#  ('the', 'jury'),
#  ('the', ','),
#  ('the', 'said'),
#  ('the', 'Department'),
#  ('jury', 'said'),
#  ('jury', 'the'),
#  ('jury', ','),
#  ('jury', ','),
#  ('said', ','),
#  ('said', 'jury'),
#  ('said', '``'),
#  ('said', 'the'),
#  (',', '``'),
#  (',', 'said'),
#  (',', 'is'),
#  (',', 'jury'),
#  ('``', 'is'),
#  ('``', ','),
#  ('``', 'lacking'),
#  ('``', 'said'),
#  ('is', 'lacking'),
#  ('is', '``'),
#  ('is', 'in'),
#  ('is', ','),
#  ('lacking', 'in'),
#  ('lacking', 'is'),
#  ('lacking', 'experienced'),
#  ('lacking', '``'),
#  ('in', 'experienced'),
#  ('in', 'lacking'),
#  ('in', 'clerical'),
#  ('in', 'is'),
#  ('experienced', 'clerical'),
#  ('experienced', 'in'),
#  ('experienced', 'personnel'),
#  ('experienced', 'lacking'),
#  ('clerical', 'personnel'),
#  ...]

# %%
co_matrix = Counter(skipgrams)
co_matrix
# Out:
# Counter({('Fulton', 'County'): 6,
#          ('Fulton', 'The'): 1,
#          ('Fulton', 'Grand'): 1,
#          ('County', 'Grand'): 1,
#          ('County', 'Fulton'): 6,
#          ('County', 'Jury'): 1,
#          ('County', 'The'): 1,
#          ('Grand', 'Jury'): 2,
#          ('Grand', 'County'): 1,
#          ('Grand', 'said'): 1,
#          ('Grand', 'Fulton'): 1,
#          ('Jury', 'said'): 1,
#          ('Jury', 'Grand'): 2,
#          ('Jury', 'Friday'): 1,
#          ('Jury', 'County'): 1,
#          ('said', 'Friday'): 5,
#          ('said', 'Jury'): 1,
#          ('said', 'an'): 2,
#          ('said', 'Grand'): 1,
#          ('Friday', 'an'): 1,
#          ('Friday', 'said'): 5,
#          ('Friday', 'investigation'): 1,
#          ('Friday', 'Jury'): 1,
#          ('an', 'investigation'): 3,
#          ('an', 'Friday'): 1,
#          ('an', 'of'): 25,
#          ('an', 'said'): 2,
#          ('investigation', 'of'): 4,
#          ('investigation', 'an'): 3,
#          ('investigation', "Atlanta's"): 1,
#          ('investigation', 'Friday'): 1,
#          ('of', "Atlanta's"): 1,
#          ('of', 'investigation'): 4,
#          ('of', 'recent'): 3,
#          ('of', 'an'): 25,
#          ("Atlanta's", 'recent'): 1,
#          ("Atlanta's", 'of'): 1,
#          ("Atlanta's", 'primary'): 1,
#          ("Atlanta's", 'investigation'): 1,
#          ('recent', 'primary'): 1,
#          ('recent', "Atlanta's"): 1,
#          ('recent', 'election'): 2,
#          ('recent', 'of'): 3,
#          ('primary', 'election'): 2,
#          ('primary', 'recent'): 1,
#          ('primary', 'produced'): 1,
#          ('primary', "Atlanta's"): 1,
#          ('election', 'produced'): 1,
#          ('election', 'primary'): 2,
#          ('election', '``'): 4,
#          ('election', 'recent'): 2,
#          ('produced', '``'): 1,
#          ('produced', 'election'): 1,
#          ('produced', 'no'): 1,
#          ('produced', 'primary'): 1,
#          ('``', 'no'): 2,
#          ('``', 'produced'): 1,
#          ('``', 'evidence'): 2,
#          ('``', 'election'): 4,
#          ('no', 'evidence'): 2,
#          ('no', '``'): 2,
#          ('no', "''"): 1,
#          ('no', 'produced'): 1,
#          ('evidence', "''"): 2,
#          ('evidence', 'no'): 2,
#          ('evidence', 'that'): 4,
#          ('evidence', '``'): 2,
#          ("''", 'that'): 8,
#          ("''", 'evidence'): 2,
#          ("''", 'any'): 2,
#          ("''", 'no'): 1,
#          ('that', 'any'): 4,
#          ('that', "''"): 8,
#          ('that', 'irregularities'): 1,
#          ('that', 'evidence'): 4,
#          ('any', 'irregularities'): 1,
#          ('any', 'that'): 4,
#          ('any', 'took'): 1,
#          ('any', "''"): 2,
#          ('irregularities', 'took'): 1,
#          ('irregularities', 'any'): 1,
#          ('irregularities', 'place'): 1,
#          ('irregularities', 'that'): 1,
#          ('took', 'place'): 4,
#          ('took', 'irregularities'): 1,
#          ('took', '.'): 4,
#          ('took', 'any'): 1,
#          ('place', '.'): 5,
#          ('place', 'took'): 4,
#          ('place', 'irregularities'): 1,
#          ('jury', 'further'): 1,
#          ('jury', 'The'): 11,
#          ('jury', 'said'): 8,
#          ('further', 'said'): 3,
#          ('further', 'jury'): 1,
#          ('further', 'in'): 3,
#          ('further', 'The'): 1,
#          ('said', 'in'): 7,
#          ('said', 'further'): 3,
#          ('said', 'term-end'): 1,
#          ('said', 'jury'): 8,
#          ('in', 'term-end'): 1,
#          ('in', 'said'): 7,
#          ('in', 'presentments'): 1,
#          ('in', 'further'): 3,
#          ('term-end', 'presentments'): 1,
#          ('term-end', 'in'): 1,
#          ('term-end', 'that'): 1,
#          ('term-end', 'said'): 1,
#          ('presentments', 'that'): 1,
#          ('presentments', 'term-end'): 1,
#          ('presentments', 'the'): 1,
#          ('presentments', 'in'): 1,
#          ('that', 'the'): 137,
#          ('that', 'presentments'): 1,
#          ('that', 'City'): 1,
#          ('that', 'term-end'): 1,
#          ('the', 'City'): 9,
#          ('the', 'that'): 137,
#          ('the', 'Executive'): 2,
#          ('the', 'presentments'): 1,
#          ('City', 'Executive'): 1,
#          ('City', 'the'): 9,
#          ('City', 'Committee'): 1,
#          ('City', 'that'): 1,
#          ('Executive', 'Committee'): 2,
#          ('Executive', 'City'): 1,
#          ('Executive', ','): 1,
#          ('Executive', 'the'): 2,
#          ('Committee', ','): 5,
#          ('Committee', 'Executive'): 2,
#          ('Committee', 'which'): 1,
#          ('Committee', 'City'): 1,
#          (',', 'which'): 57,
#          (',', 'Committee'): 5,
#          (',', 'had'): 19,
#          (',', 'Executive'): 1,
#          ('which', 'had'): 7,
#          ('which', ','): 57,
#          ('which', 'over-all'): 1,
#          ('which', 'Committee'): 1,
#          ('had', 'over-all'): 1,
#          ('had', 'which'): 7,
#          ('had', 'charge'): 1,
#          ('had', ','): 19,
#          ('over-all', 'charge'): 1,
#          ('over-all', 'had'): 1,
#          ('over-all', 'of'): 2,
#          ('over-all', 'which'): 1,
#          ('charge', 'of'): 7,
#          ('charge', 'over-all'): 1,
#          ('charge', 'the'): 5,
#          ('charge', 'had'): 1,
#          ('of', 'the'): 909,
#          ('of', 'charge'): 7,
#          ('of', 'election'): 3,
#          ('of', 'over-all'): 2,
#          ('the', 'election'): 15,
#          ('the', 'of'): 908,
#          ('the', ','): 521,
#          ('the', 'charge'): 5,
#          ('election', ','): 8,
#          ('election', 'the'): 15,
#          ('election', 'of'): 3,
#          (',', '``'): 87,
#          (',', 'election'): 8,
#          (',', 'deserves'): 1,
#          (',', 'the'): 521,
#          ('``', 'deserves'): 1,
#          ('``', ','): 84,
#          ('``', 'the'): 40,
#          ('deserves', 'the'): 1,
#          ('deserves', '``'): 1,
#          ('deserves', 'praise'): 1,
#          ('deserves', ','): 1,
#          ('the', 'praise'): 1,
#          ('the', 'deserves'): 1,
#          ('the', 'and'): 213,
#          ('the', '``'): 44,
#          ('praise', 'and'): 1,
#          ('praise', 'the'): 1,
#          ('praise', 'thanks'): 1,
#          ('praise', 'deserves'): 1,
#          ('and', 'thanks'): 1,
#          ('and', 'praise'): 1,
#          ('and', 'of'): 103,
#          ('and', 'the'): 213,
#          ('thanks', 'of'): 1,
#          ('thanks', 'and'): 1,
#          ('thanks', 'the'): 1,
#          ('thanks', 'praise'): 1,
#          ('of', 'thanks'): 1,
#          ('of', 'City'): 8,
#          ('of', 'and'): 103,
#          ('the', 'thanks'): 1,
#          ('City', 'of'): 8,
#          ('City', 'Atlanta'): 1,
#          ('of', 'Atlanta'): 8,
#          ('of', "''"): 23,
#          ('Atlanta', "''"): 1,
#          ('Atlanta', 'of'): 8,
#          ('Atlanta', 'for'): 1,
#          ('Atlanta', 'City'): 1,
#          ("''", 'for'): 13,
#          ("''", 'Atlanta'): 1,
#          ("''", 'the'): 83,
#          ("''", 'of'): 23,
#          ('for', 'the'): 205,
#          ('for', "''"): 13,
#          ('for', 'manner'): 1,
#          ('for', 'Atlanta'): 1,
#          ('the', 'manner'): 2,
#          ('the', 'for'): 205,
#          ('the', 'in'): 451,
#          ('the', "''"): 83,
#          ('manner', 'in'): 3,
#          ('manner', 'the'): 2,
#          ('manner', 'which'): 2,
#          ('manner', 'for'): 1,
#          ('in', 'which'): 16,
#          ('in', 'manner'): 3,
#          ('in', 'the'): 451,
#          ('which', 'the'): 24,
#          ('which', 'in'): 16,
#          ('which', 'election'): 1,
#          ('which', 'manner'): 2,
#          ('the', 'which'): 24,
#          ('the', 'was'): 82,
#          ('election', 'was'): 2,
#          ('election', 'conducted'): 1,
#          ('election', 'which'): 1,
#          ('was', 'conducted'): 1,
#          ('was', 'election'): 2,
#          ('was', '.'): 17,
#          ('was', 'the'): 82,
#          ('conducted', '.'): 1,
#          ('conducted', 'was'): 1,
#          ('conducted', 'election'): 1,
#          ('September-October', 'term'): 1,
#          ('September-October', 'The'): 1,
#          ('September-October', 'jury'): 1,
#          ('term', 'jury'): 1,
#          ('term', 'September-October'): 1,
#          ('term', 'had'): 1,
#          ('term', 'The'): 1,
#          ('jury', 'had'): 1,
#          ('jury', 'term'): 1,
#          ('jury', 'been'): 1,
#          ('jury', 'September-October'): 1,
#          ('had', 'been'): 37,
#          ('had', 'jury'): 1,
#          ('had', 'charged'): 2,
#          ('had', 'term'): 1,
#          ('been', 'charged'): 1,
#          ('been', 'had'): 37,
#          ('been', 'by'): 10,
#          ('been', 'jury'): 1,
#          ('charged', 'by'): 1,
#          ('charged', 'been'): 1,
#          ('charged', 'Fulton'): 1,
#          ('charged', 'had'): 2,
#          ('by', 'Fulton'): 1,
#          ('by', 'charged'): 1,
#          ('by', 'Superior'): 1,
#          ('by', 'been'): 10,
#          ('Fulton', 'Superior'): 2,
#          ('Fulton', 'by'): 1,
#          ('Fulton', 'Court'): 2,
#          ('Fulton', 'charged'): 1,
#          ('Superior', 'Court'): 5,
#          ('Superior', 'Fulton'): 2,
#          ('Superior', 'Judge'): 1,
#          ('Superior', 'by'): 1,
#          ('Court', 'Judge'): 1,
#          ('Court', 'Superior'): 5,
#          ('Court', 'Durwood'): 1,
#          ('Court', 'Fulton'): 2,
#          ('Judge', 'Durwood'): 1,
#          ('Judge', 'Court'): 1,
#          ('Judge', 'Pye'): 1,
#          ('Judge', 'Superior'): 1,
#          ('Durwood', 'Pye'): 1,
#          ('Durwood', 'Judge'): 1,
#          ('Durwood', 'to'): 1,
#          ('Durwood', 'Court'): 1,
#          ('Pye', 'to'): 1,
#          ('Pye', 'Durwood'): 1,
#          ('Pye', 'investigate'): 1,
#          ('Pye', 'Judge'): 1,
#          ('to', 'investigate'): 3,
#          ('to', 'Pye'): 1,
#          ('to', 'reports'): 1,
#          ('to', 'Durwood'): 1,
#          ('investigate', 'reports'): 1,
#          ('investigate', 'to'): 3,
#          ('investigate', 'of'): 1,
#          ('investigate', 'Pye'): 1,
#          ('reports', 'of'): 5,
#          ('reports', 'investigate'): 1,
#          ('reports', 'possible'): 1,
#          ('reports', 'to'): 1,
#          ('of', 'possible'): 2,
#          ('of', 'reports'): 5,
#          ('of', '``'): 25,
#          ('of', 'investigate'): 1,
#          ('possible', '``'): 1,
#          ('possible', 'of'): 2,
#          ('possible', 'irregularities'): 1,
#          ('possible', 'reports'): 1,
#          ('``', 'irregularities'): 1,
#          ('``', 'possible'): 1,
#          ('``', "''"): 52,
#          ('``', 'of'): 23,
#          ('irregularities', "''"): 1,
#          ('irregularities', '``'): 1,
#          ('irregularities', 'in'): 1,
#          ('irregularities', 'possible'): 1,
#          ("''", 'in'): 17,
#          ("''", 'irregularities'): 1,
#          ("''", '``'): 55,
#          ('in', "''"): 18,
#          ('in', 'hard-fought'): 1,
#          ('in', 'irregularities'): 1,
#          ('the', 'hard-fought'): 1,
#          ('the', 'primary'): 8,
#          ('hard-fought', 'primary'): 1,
#          ('hard-fought', 'the'): 1,
#          ('hard-fought', 'which'): 1,
#          ('hard-fought', 'in'): 1,
#          ('primary', 'which'): 2,
#          ('primary', 'hard-fought'): 1,
#          ('primary', 'was'): 1,
#          ('primary', 'the'): 8,
#          ('which', 'was'): 7,
#          ('which', 'primary'): 2,
#          ('which', 'won'): 2,
#          ('which', 'hard-fought'): 1,
#          ('was', 'won'): 1,
#          ('was', 'which'): 7,
#          ('was', 'by'): 29,
#          ('was', 'primary'): 1,
#          ('won', 'by'): 3,
#          ('won', 'was'): 1,
#          ('won', 'Mayor-nominate'): 1,
#          ('won', 'which'): 2,
#          ('by', 'Mayor-nominate'): 1,
#          ('by', 'won'): 3,
#          ('by', 'Ivan'): 2,
#          ('by', 'was'): 29,
#          ('Mayor-nominate', 'Ivan'): 1,
#          ('Mayor-nominate', 'by'): 1,
#          ('Mayor-nominate', 'Allen'): 1,
#          ('Mayor-nominate', 'won'): 1,
#          ('Ivan', 'Allen'): 2,
#          ('Ivan', 'Mayor-nominate'): 1,
#          ('Ivan', 'Jr.'): 2,
#          ('Ivan', 'by'): 2,
#          ('Allen', 'Jr.'): 2,
#          ('Allen', 'Ivan'): 2,
#          ('Allen', '.'): 1,
#          ('Allen', 'Mayor-nominate'): 1,
#          ('Jr.', '.'): 3,
#          ('Jr.', 'Allen'): 2,
#          ('Jr.', 'Ivan'): 2,
#          ('Only', 'a'): 1,
#          ('Only', '``'): 1,
#          ('Only', 'relative'): 1,
#          ('a', 'relative'): 1,
#          ('a', 'Only'): 1,
#          ('a', 'handful'): 1,
#          ('a', '``'): 33,
#          ('relative', 'handful'): 1,
#          ('relative', 'a'): 1,
#          ('relative', 'of'): 2,
#          ('relative', 'Only'): 1,
#          ('handful', 'of'): 1,
#          ('handful', 'relative'): 1,
#          ('handful', 'such'): 1,
#          ('handful', 'a'): 1,
#          ('of', 'such'): 6,
#          ('of', 'handful'): 1,
#          ('of', 'relative'): 2,
#          ('such', 'reports'): 1,
#          ('such', 'of'): 6,
#          ('such', 'was'): 1,
#          ('such', 'handful'): 1,
#          ('reports', 'was'): 1,
#          ('reports', 'such'): 1,
#          ('reports', 'received'): 1,
#          ('was', 'received'): 1,
#          ('was', 'reports'): 1,
#          ('was', "''"): 2,
#          ('was', 'such'): 1,
#          ('received', "''"): 1,
#          ('received', 'was'): 1,
#          ('received', ','): 6,
#          ('received', 'reports'): 1,
#          ("''", ','): 153,
#          ("''", 'received'): 1,
#          ("''", 'was'): 2,
#          (',', "''"): 153,
#          (',', 'jury'): 17,
#          (',', 'received'): 6,
#          ('the', 'jury'): 27,
#          ('the', 'said'): 75,
#          ('jury', 'the'): 27,
#          ('jury', ','): 17,
#          ('said', ','): 225,
#          ('said', '``'): 33,
#          ('said', 'the'): 75,
#          (',', 'said'): 225,
#          (',', 'considering'): 1,
#          ('``', 'considering'): 1,
#          ('``', 'said'): 33,
#          ('considering', 'the'): 1,
#          ('considering', '``'): 1,
#          ('considering', 'widespread'): 1,
#          ('considering', ','): 1,
#          ('the', 'widespread'): 1,
#          ('the', 'considering'): 1,
#          ('the', 'interest'): 6,
#          ('widespread', 'interest'): 1,
#          ('widespread', 'the'): 1,
#          ('widespread', 'in'): 1,
#          ('widespread', 'considering'): 1,
#          ('interest', 'in'): 6,
#          ('interest', 'widespread'): 1,
#          ('interest', 'the'): 6,
#          ('in', 'interest'): 6,
#          ('in', 'election'): 5,
#          ('in', 'widespread'): 1,
#          ('election', 'in'): 5,
#          (',', 'number'): 1,
#          ('the', 'number'): 5,
#          ('number', 'of'): 21,
#          ('number', 'the'): 5,
#          ('number', 'voters'): 1,
#          ('number', ','): 1,
#          ('of', 'voters'): 3,
#          ('of', 'number'): 21,
#          ('voters', 'and'): 1,
#          ('voters', 'of'): 3,
#          ('voters', 'the'): 5,
#          ('voters', 'number'): 1,
#          ('and', 'voters'): 1,
#          ('and', 'size'): 3,
#          ('the', 'size'): 3,
#          ('the', 'voters'): 5,
#          ('size', 'of'): 1,
#          ('size', 'the'): 3,
#          ('size', 'this'): 1,
#          ('size', 'and'): 3,
#          ('of', 'this'): 19,
#          ('of', 'size'): 1,
#          ('of', 'city'): 8,
#          ('this', 'city'): 2,
#          ('this', 'of'): 19,
#          ('this', "''"): 18,
#          ('this', 'size'): 1,
#          ('city', "''"): 1,
#          ('city', 'this'): 2,
#          ('city', '.'): 7,
#          ('city', 'of'): 8,
#          ("''", '.'): 194,
#          ("''", 'city'): 1,
#          ("''", 'this'): 18,
#          ('jury', 'it'): 3,
#          ('said', 'it'): 16,
#          ('said', 'did'): 3,
#          ('said', 'The'): 18,
#          ('it', 'did'): 3,
#          ('it', 'said'): 16,
#          ('it', 'find'): 5,
#          ('it', 'jury'): 3,
#          ('did', 'find'): 1,
#          ('did', 'it'): 3,
#          ('did', 'that'): 3,
#          ('did', 'said'): 3,
#          ('find', 'that'): 2,
#          ('find', 'did'): 1,
#          ('find', 'many'): 1,
#          ('find', 'it'): 5,
#          ('that', 'many'): 6,
#          ('that', 'find'): 2,
#          ('that', 'of'): 25,
#          ('that', 'did'): 3,
#          ('many', 'of'): 9,
#          ('many', 'that'): 6,
#          ('many', "Georgia's"): 1,
#          ('many', 'find'): 1,
#          ('of', "Georgia's"): 5,
#          ('of', 'many'): 9,
#          ('of', 'registration'): 1,
#          ('of', 'that'): 25,
#          ("Georgia's", 'registration'): 1,
#          ("Georgia's", 'of'): 4,
#          ("Georgia's", 'and'): 1,
#          ("Georgia's", 'many'): 1,
#          ('registration', 'and'): 1,
#          ('registration', "Georgia's"): 1,
#          ('registration', 'election'): 1,
#          ('registration', 'of'): 1,
#          ('and', 'election'): 3,
#          ('and', 'registration'): 1,
#          ('and', 'laws'): 2,
#          ('and', "Georgia's"): 1,
#          ('election', 'laws'): 1,
#          ('election', 'and'): 3,
#          ('election', 'registration'): 1,
#          ('laws', '``'): 1,
#          ('laws', 'election'): 1,
#          ('laws', 'are'): 1,
#          ('laws', 'and'): 2,
#          ('``', 'are'): 9,
#          ('``', 'laws'): 1,
#          ('``', 'outmoded'): 1,
#          ('are', 'outmoded'): 1,
#          ('are', '``'): 12,
#          ('are', 'or'): 1,
#          ('are', 'laws'): 1,
#          ('outmoded', 'or'): 1,
#          ('outmoded', 'are'): 1,
#          ('outmoded', 'inadequate'): 1,
#          ('outmoded', '``'): 1,
#          ('or', 'inadequate'): 1,
#          ('or', 'outmoded'): 1,
#          ('or', 'and'): 2,
#          ('or', 'are'): 1,
#          ('inadequate', 'and'): 1,
#          ('inadequate', 'or'): 1,
#          ('inadequate', 'often'): 1,
#          ('inadequate', 'outmoded'): 1,
#          ('and', 'often'): 1,
#          ('and', 'inadequate'): 1,
#          ('and', 'ambiguous'): 1,
#          ('and', 'or'): 2,
#          ('often', 'ambiguous'): 1,
#          ('often', 'and'): 1,
#          ('often', "''"): 1,
#          ('often', 'inadequate'): 1,
#          ('ambiguous', "''"): 1,
#          ('ambiguous', 'often'): 1,
#          ('ambiguous', '.'): 1,
#          ('ambiguous', 'and'): 1,
#          ("''", 'ambiguous'): 1,
#          ("''", 'often'): 1,
#          ('recommended', 'that'): 5,
#          ('recommended', 'It'): 1,
#          ('recommended', 'Fulton'): 1,
#          ('that', 'Fulton'): 1,
#          ('that', 'recommended'): 5,
#          ('that', 'legislators'): 2,
#          ('that', 'It'): 8,
#          ('Fulton', 'legislators'): 1,
#          ('Fulton', 'that'): 1,
#          ('Fulton', 'act'): 1,
#          ('Fulton', 'recommended'): 1,
#          ('legislators', 'act'): 1,
#          ('legislators', 'Fulton'): 2,
#          ('legislators', '``'): 2,
#          ('legislators', 'that'): 2,
#          ('act', '``'): 2,
#          ('act', 'legislators'): 1,
#          ('act', 'to'): 1,
#          ('act', 'Fulton'): 1,
#          ('``', 'to'): 21,
#          ('``', 'act'): 2,
#          ('``', 'have'): 3,
#          ('``', 'legislators'): 2,
#          ('to', 'have'): 32,
#          ('to', '``'): 22,
#          ('to', 'these'): 5,
#          ('to', 'act'): 1,
#          ('have', 'these'): 4,
#          ('have', 'to'): 32,
#          ('have', 'laws'): 1,
#          ('have', '``'): 8,
#          ('these', 'laws'): 2,
#          ('these', 'have'): 4,
#          ('these', 'studied'): 1,
#          ('these', 'to'): 5,
#          ('laws', 'studied'): 1,
#          ('laws', 'these'): 2,
#          ('laws', 'have'): 1,
#          ('studied', 'and'): 1,
#          ('studied', 'laws'): 1,
#          ('studied', 'revised'): 1,
#          ('studied', 'these'): 1,
#          ('and', 'revised'): 1,
#          ('and', 'studied'): 1,
#          ('and', 'to'): 45,
#          ('revised', 'to'): 1,
#          ('revised', 'and'): 1,
#          ('revised', 'the'): 1,
#          ('revised', 'studied'): 1,
#          ('to', 'the'): 353,
#          ('to', 'revised'): 1,
#          ('to', 'end'): 10,
#          ('to', 'and'): 45,
#          ('the', 'end'): 13,
#          ('the', 'to'): 353,
#          ('the', 'revised'): 1,
#          ('end', 'of'): 7,
#          ('end', 'the'): 13,
#          ('end', 'modernizing'): 1,
#          ('end', 'to'): 10,
#          ('of', 'modernizing'): 1,
#          ('of', 'end'): 7,
#          ('modernizing', 'and'): 1,
#          ('modernizing', 'of'): 1,
#          ('modernizing', 'improving'): 1,
#          ('modernizing', 'end'): 1,
#          ('and', 'improving'): 1,
#          ('and', 'modernizing'): 1,
#          ('and', 'them'): 4,
#          ('improving', 'them'): 1,
#          ('improving', 'and'): 1,
#          ('improving', "''"): 1,
#          ('improving', 'modernizing'): 1,
#          ('them', "''"): 5,
#          ('them', 'improving'): 1,
#          ('them', '.'): 11,
#          ('them', 'and'): 4,
#          ("''", 'them'): 5,
#          ("''", 'improving'): 1,
#          ('grand', 'jury'): 6,
#          ('grand', 'The'): 2,
#          ('grand', 'commented'): 1,
#          ('jury', 'commented'): 2,
#          ('jury', 'grand'): 6,
#          ('jury', 'on'): 3,
#          ('commented', 'on'): 2,
#          ('commented', 'jury'): 2,
#          ('commented', 'a'): 1,
#          ('commented', 'grand'): 1,
#          ('on', 'a'): 53,
#          ('on', 'commented'): 2,
#          ('on', 'number'): 1,
#          ('on', 'jury'): 3,
#          ('a', 'number'): 14,
#          ('a', 'on'): 52,
#          ('a', 'of'): 252,
#          ('a', 'commented'): 1,
#          ('number', 'a'): 14,
#          ('number', 'other'): 3,
#          ('number', 'on'): 1,
#          ('of', 'other'): 16,
#          ('of', 'topics'): 1,
#          ('of', 'a'): 253,
#          ('other', 'topics'): 1,
#          ('other', 'of'): 16,
#          ('other', ','): 14,
#          ('other', 'number'): 3,
#          ('topics', ','): 1,
#          ('topics', 'other'): 1,
#          ('topics', 'among'): 1,
#          ('topics', 'of'): 1,
#          (',', 'among'): 6,
#          (',', 'topics'): 1,
#          (',', 'them'): 8,
#          (',', 'other'): 14,
#          ('among', 'them'): 1,
#          ('among', ','): 6,
#          ('among', 'the'): 11,
#          ('among', 'topics'): 1,
#          ('them', 'the'): 7,
#          ('them', 'among'): 1,
#          ('them', 'Atlanta'): 1,
#          ('them', ','): 8,
#          ('the', 'Atlanta'): 5,
#          ('the', 'them'): 7,
#          ('the', 'among'): 11,
#          ('Atlanta', 'and'): 3,
#          ('Atlanta', 'the'): 5,
#          ('Atlanta', 'Fulton'): 1,
#          ('Atlanta', 'them'): 1,
#          ('and', 'Fulton'): 2,
#          ('and', 'Atlanta'): 3,
#          ('and', 'County'): 4,
#          ('Fulton', 'and'): 2,
#          ('Fulton', 'purchasing'): 1,
#          ('Fulton', 'Atlanta'): 1,
#          ('County', 'purchasing'): 1,
#          ('County', 'departments'): 1,
#          ('County', 'and'): 4,
#          ('purchasing', 'departments'): 1,
#          ('purchasing', 'County'): 1,
#          ('purchasing', 'which'): 1,
#          ('purchasing', 'Fulton'): 1,
#          ('departments', 'which'): 1,
#          ('departments', 'purchasing'): 1,
#          ('departments', 'it'): 1,
#          ('departments', 'County'): 1,
#          ('which', 'it'): 5,
#          ('which', 'departments'): 1,
#          ('which', 'said'): 5,
#          ('which', 'purchasing'): 1,
#          ('it', 'which'): 5,
#          ('it', '``'): 6,
#          ('it', 'departments'): 1,
#          ('said', 'are'): 2,
#          ('said', 'which'): 5,
#          ('``', 'well'): 1,
#          ('``', 'it'): 5,
#          ('are', 'well'): 1,
#          ('are', 'operated'): 1,
#          ('are', 'said'): 2,
#          ('well', 'operated'): 1,
#          ('well', 'are'): 1,
#          ('well', 'and'): 2,
#          ('well', '``'): 1,
#          ('operated', 'and'): 2,
#          ('operated', 'well'): 1,
#          ('operated', 'follow'): 1,
#          ('operated', 'are'): 1,
#          ('and', 'follow'): 1,
#          ('and', 'operated'): 2,
#          ('and', 'generally'): 1,
#          ('and', 'well'): 2,
#          ('follow', 'generally'): 1,
#          ('follow', 'and'): 1,
#          ('follow', 'accepted'): 1,
#          ('follow', 'operated'): 1,
#          ('generally', 'accepted'): 1,
#          ('generally', 'follow'): 1,
#          ('generally', 'practices'): 1,
#          ('generally', 'and'): 1,
#          ('accepted', 'practices'): 1,
#          ('accepted', 'generally'): 1,
#          ('accepted', 'which'): 1,
#          ('accepted', 'follow'): 1,
#          ('practices', 'which'): 1,
#          ('practices', 'accepted'): 1,
#          ('practices', 'inure'): 1,
#          ('practices', 'generally'): 1,
#          ('which', 'inure'): 1,
#          ('which', 'practices'): 1,
#          ('which', 'to'): 10,
#          ('which', 'accepted'): 1,
#          ('inure', 'to'): 1,
#          ('inure', 'which'): 1,
#          ('inure', 'the'): 1,
#          ('inure', 'practices'): 1,
#          ('to', 'inure'): 1,
#          ('to', 'best'): 1,
#          ('to', 'which'): 10,
#          ('the', 'best'): 9,
#          ('the', 'inure'): 1,
#          ('best', 'interest'): 1,
#          ('best', 'the'): 9,
#          ('best', 'of'): 1,
#          ('best', 'to'): 1,
#          ('interest', 'of'): 2,
#          ('interest', 'best'): 1,
#          ('interest', 'both'): 1,
#          ('of', 'both'): 11,
#          ('of', 'interest'): 2,
#          ('of', 'governments'): 1,
#          ('of', 'best'): 1,
#          ('both', 'governments'): 1,
#          ('both', 'of'): 11,
#          ('both', "''"): 2,
#          ('both', 'interest'): 1,
#          ('governments', "''"): 1,
#          ('governments', 'both'): 1,
#          ('governments', '.'): 1,
#          ('governments', 'of'): 1,
#          ("''", 'governments'): 1,
#          ("''", 'both'): 2,
#          (',', 'However'): 7,
#          ('the', 'However'): 2,
#          ('said', 'believes'): 1,
#          ('it', 'believes'): 2,
#          ('believes', '``'): 2,
#          ('believes', 'it'): 2,
#          ('believes', 'these'): 1,
#          ('believes', 'said'): 1,
#          ('``', 'these'): 3,
#          ('``', 'believes'): 2,
#          ('``', 'two'): 2,
#          ('these', 'two'): 2,
#          ('these', '``'): 4,
#          ('these', 'offices'): 1,
#          ('these', 'believes'): 1,
#          ('two', 'offices'): 1,
#          ('two', 'these'): 2,
#          ('two', 'should'): 1,
#          ('two', '``'): 2,
#          ('offices', 'should'): 1,
#          ('offices', 'two'): 1,
#          ('offices', 'be'): 1,
#          ('offices', 'these'): 1,
#          ('should', 'be'): 25,
#          ('should', 'offices'): 1,
#          ('should', 'combined'): 1,
#          ('should', 'two'): 1,
#          ('be', 'combined'): 1,
#          ('be', 'should'): 25,
#          ('be', 'to'): 103,
#          ('be', 'offices'): 1,
#          ('combined', 'to'): 3,
#          ('combined', 'be'): 1,
#          ('combined', 'achieve'): 1,
#          ('combined', 'should'): 1,
#          ('to', 'achieve'): 4,
#          ('to', 'combined'): 3,
#          ('to', 'greater'): 4,
#          ('to', 'be'): 103,
#          ('achieve', 'greater'): 1,
#          ('achieve', 'to'): 4,
#          ('achieve', 'efficiency'): 1,
#          ('achieve', 'combined'): 1,
#          ('greater', 'efficiency'): 1,
#          ('greater', 'achieve'): 1,
#          ('greater', 'and'): 2,
#          ('greater', 'to'): 4,
#          ('efficiency', 'and'): 1,
#          ('efficiency', 'greater'): 1,
#          ('efficiency', 'reduce'): 1,
#          ('efficiency', 'achieve'): 1,
#          ('and', 'reduce'): 1,
#          ('and', 'efficiency'): 1,
#          ('and', 'greater'): 2,
#          ('reduce', 'the'): 4,
#          ('reduce', 'and'): 1,
#          ('reduce', 'cost'): 1,
#          ('reduce', 'efficiency'): 1,
#          ('the', 'cost'): 5,
#          ('the', 'reduce'): 4,
#          ('cost', 'of'): 8,
#          ('cost', 'the'): 5,
#          ('cost', 'administration'): 1,
#          ('cost', 'reduce'): 1,
#          ('of', 'administration'): 5,
#          ('of', 'cost'): 8,
#          ('administration', "''"): 1,
#          ('administration', 'of'): 5,
#          ('administration', '.'): 6,
#          ('administration', 'cost'): 1,
#          ("''", 'administration'): 1,
#          ('City', 'Purchasing'): 1,
#          ('City', 'The'): 2,
#          ('City', 'Department'): 1,
#          ('Purchasing', 'Department'): 1,
#          ('Purchasing', 'City'): 1,
#          ('Purchasing', ','): 1,
#          ('Purchasing', 'The'): 1,
#          ('Department', ','): 3,
#          ('Department', 'Purchasing'): 1,
#          ('Department', 'the'): 6,
#          ('Department', 'City'): 1,
#          (',', 'Department'): 3,
#          (',', 'Purchasing'): 1,
#          ('the', 'Department'): 6,
#          (',', 'is'): 66,
#          ('``', 'is'): 16,
#          ('``', 'lacking'): 1,
#          ('is', 'lacking'): 1,
#          ('is', '``'): 28,
#          ('is', 'in'): 25,
#          ('is', ','): 66,
#          ('lacking', 'in'): 2,
#          ('lacking', 'is'): 1,
#          ('lacking', 'experienced'): 1,
#          ('lacking', '``'): 1,
#          ('in', 'experienced'): 1,
#          ('in', 'lacking'): 2,
#          ('in', 'clerical'): 1,
#          ('in', 'is'): 25,
#          ('experienced', 'clerical'): 1,
#          ('experienced', 'in'): 1,
#          ('experienced', 'personnel'): 1,
#          ('experienced', 'lacking'): 1,
#          ('clerical', 'personnel'): 1,
#          ('clerical', 'experienced'): 1,
#          ('clerical', 'as'): 1,
#          ('clerical', 'in'): 1,
#          ('personnel', 'as'): 1,
#          ('personnel', 'clerical'): 1,
#          ('personnel', 'a'): 1,
#          ('personnel', 'experienced'): 1,
#          ('as', 'a'): 61,
#          ('as', 'personnel'): 1,
#          ('as', 'result'): 10,
#          ('as', 'clerical'): 1,
#          ('a', 'result'): 13,
#          ('a', 'as'): 61,
#          ('a', 'personnel'): 1,
#          ('result', 'of'): 11,
#          ('result', 'a'): 13,
#          ('result', 'city'): 1,
#          ('result', 'as'): 10,
#          ('of', 'result'): 11,
#          ('of', 'personnel'): 1,
#          ('city', 'personnel'): 1,
#          ('city', 'policies'): 1,
#          ('city', 'result'): 1,
#          ('personnel', 'policies'): 1,
#          ('personnel', 'city'): 1,
#          ('personnel', "''"): 1,
#          ('personnel', 'of'): 1,
#          ('policies', "''"): 1,
#          ('policies', 'personnel'): 1,
#          ('policies', '.'): 2,
#          ('policies', 'city'): 1,
#          ("''", 'policies'): 1,
#          ("''", 'personnel'): 1,
#          ('urged', 'that'): 3,
#          ('urged', 'It'): 2,
#          ('urged', 'the'): 4,
#          ('that', 'urged'): 3,
#          ('that', 'city'): 3,
#          ('the', 'city'): 29,
#          ('the', 'urged'): 4,
#          ('city', '``'): 2,
#          ('city', 'the'): 29,
#          ('city', 'take'): 1,
#          ('city', 'that'): 3,
#          ('``', 'take'): 3,
#          ('``', 'city'): 2,
#          ('``', 'steps'): 1,
#          ('take', 'steps'): 2,
#          ('take', '``'): 5,
#          ('take', 'to'): 12,
#          ('take', 'city'): 1,
#          ('steps', 'to'): 3,
#          ('steps', 'take'): 2,
#          ('steps', 'remedy'): 1,
#          ('steps', '``'): 1,
#          ('to', 'remedy'): 1,
#          ('to', 'steps'): 3,
#          ('to', "''"): 25,
#          ('to', 'take'): 12,
#          ('remedy', "''"): 1,
#          ('remedy', 'to'): 1,
#          ('remedy', 'this'): 1,
#          ('remedy', 'steps'): 1,
#          ("''", 'remedy'): 1,
#          ("''", 'problem'): 1,
#          ("''", 'to'): 25,
#          ('this', 'problem'): 2,
#          ('this', '.'): 28,
#          ('this', 'remedy'): 1,
#          ('problem', '.'): 3,
#          ('problem', 'this'): 2,
#          ('problem', "''"): 2,
#          ('of', 'Implementation'): 1,
#          ('of', 'automobile'): 1,
#          ("Georgia's", 'automobile'): 1,
#          ("Georgia's", 'title'): 1,
#          ("Georgia's", 'Implementation'): 1,
#          ('automobile', 'title'): 1,
#          ('automobile', "Georgia's"): 1,
#          ('automobile', 'law'): 1,
#          ('automobile', 'of'): 1,
#          ('title', 'law'): 1,
#          ('title', 'automobile'): 1,
#          ('title', 'was'): 2,
#          ('title', "Georgia's"): 1,
#          ('law', 'was'): 1,
#          ('law', 'title'): 1,
#          ('law', 'also'): 1,
#          ('law', 'automobile'): 1,
#          ('was', 'also'): 11,
#          ('was', 'law'): 1,
#          ('was', 'recommended'): 1,
#          ('was', 'title'): 2,
#          ('also', 'recommended'): 2,
#          ('also', 'was'): 11,
#          ('also', 'by'): 1,
#          ('also', 'law'): 1,
#          ('recommended', 'by'): 1,
#          ('recommended', 'also'): 2,
#          ('recommended', 'the'): 4,
#          ('recommended', 'was'): 1,
#          ('by', 'the'): 87,
#          ('by', 'recommended'): 1,
#          ('by', 'outgoing'): 1,
#          ('by', 'also'): 1,
#          ('the', 'outgoing'): 1,
#          ('the', 'by'): 87,
#          ('the', 'recommended'): 4,
#          ('outgoing', 'jury'): 1,
#          ('outgoing', 'the'): 1,
#          ('outgoing', '.'): 1,
#          ('outgoing', 'by'): 1,
#          ('jury', '.'): 6,
#          ('jury', 'outgoing'): 1,
#          ('that', 'next'): 2,
#          ('the', 'next'): 14,
#          ('the', 'Legislature'): 19,
#          ('next', 'Legislature'): 1,
#          ('next', 'the'): 14,
#          ('next', '``'): 1,
#          ('next', 'that'): 2,
#          ('Legislature', '``'): 1,
#          ('Legislature', 'next'): 1,
#          ('Legislature', 'provide'): 1,
#          ('Legislature', 'the'): 19,
#          ('``', 'provide'): 2,
#          ...})

# %% [markdown]
# ## 3. Weighting function f

# %%
def weighting(w_i, w_j, X_ik):   
    try:
        x_ij = X_ik[(w_i, w_j)]
    except:
        x_ij = 1 
    x_max = 100
    alpha = 0.75
    if x_ij < x_max:
        result = (x_ij/x_max) ** alpha
    else:
        result = 1 
        
    return result

# %%
w_i  = 'Legislature'
w_j  = 'next'
w_j2 = 'outgoing'

print(weighting(w_i, w_j, co_matrix))   
print(weighting(w_i, w_j2, co_matrix))
# Out:
# 0.03162277660168379
# 0.0

# %%
#now apply this weighting to all possible pairs
from itertools import combinations_with_replacement

counter = {} #for keeping the co-occurrences
weighting_dic = {} #for keeping all the probability after passing through the weighting function

for bigram in combinations_with_replacement(vocabs, 2):  #we need to also think its reverse
    #if this bigram exists in co_matrix
    #we gonna add this to our co-occurence matrix
    if co_matrix.get(bigram) is not None:
        cooc = co_matrix[bigram]  #get the co-occurrence
        counter[bigram] = cooc + 1 #this is again basically label smoothing....(stability issues (especially when divide something))
        counter[(bigram[1], bigram[0])] = cooc + 1  #trick to get all pairs
    else: #otherwise, do nothing
        pass
    
    #apply the weighting function using this co-occurrence matrix thingy    
    weighting_dic[bigram] = weighting(bigram[0], bigram[1], counter)
    weighting_dic[(bigram[1], bigram[0])] = weighting(bigram[1], bigram[0], counter)

# %% [markdown]
# ## 5. Prepare train data

# %%
import math

def random_batch(batch_size, word_sequence, skip_grams, X_ik, weighting_dic):
    
    #loop through this skipgram, and change it id  because when sending model, it must number
    skip_grams_id = [(word2index[skip_gram[0]], word2index[skip_gram[1]]) for skip_gram in skip_grams]
    
    #randomly pick "batch_size" indexes
    number_of_choices = len(skip_grams_id)
    random_index = np.random.choice(number_of_choices, batch_size, replace=False) #no repeating indexes among these random indexes
    
    random_inputs = [] #xi, wi (in batches)
    random_labels = [] #xj, wj (in batches)
    random_coocs  = [] #Xij (in batches)
    random_weighting = [] #f(Xij) (in batches)
    #for each of the sample in these indexes
    for i in random_index:
        random_inputs.append([skip_grams_id[i][0]]) #same reason why i put bracket here....
        random_labels.append([skip_grams_id[i][1]])
        
        #get cooc
        #first check whether it exists...
        pair = skip_grams[i]  #e.g., ('banana', 'fruit)
        try:
            cooc = X_ik[pair]
        except:
            cooc = 1 #label smoothing
            
        random_coocs.append([math.log(cooc)])  #1. why log, #2, why bracket -> size ==> (, 1)  #my neural network expects (, 1)
        
        #get weighting
        weighting = weighting_dic[pair]  #why not use try....maybe it does not exist....
        random_weighting.append(weighting)

        
    return np.array(random_inputs), np.array(random_labels), np.array(random_coocs), np.array(random_weighting)

# %% [markdown]
# ## 6. Model

# %%
class GloVe(nn.Module):
    
    def __init__(self, vocab_size,embed_size):
        super(GloVe,self).__init__()
        self.embedding_v = nn.Embedding(vocab_size, embed_size) # center embedding
        self.embedding_u = nn.Embedding(vocab_size, embed_size) # out embedding
        
        self.v_bias = nn.Embedding(vocab_size, 1)
        self.u_bias = nn.Embedding(vocab_size, 1)
        
    def forward(self, center_words, target_words, coocs, weighting):
        center_embeds = self.embedding_v(center_words) # [batch_size, 1, emb_size]
        target_embeds = self.embedding_u(target_words) # [batch_size, 1, emb_size]
        
        center_bias = self.v_bias(center_words).squeeze(1)
        target_bias = self.u_bias(target_words).squeeze(1)
        
        inner_product = target_embeds.bmm(center_embeds.transpose(1, 2)).squeeze(2)
        #[batch_size, 1, emb_size] @ [batch_size, emb_size, 1] = [batch_size, 1, 1] = [batch_size, 1]
        
        #note that coocs already got log
        loss = weighting*torch.pow(inner_product +center_bias + target_bias - coocs, 2)
        
        return torch.sum(loss)

# %%
voc_size   = len(vocabs)
batch_size = 2 
emb_size   = 2 
model      = GloVe(voc_size, emb_size)

optimizer  = optim.Adam(model.parameters(), lr=0.0001)

# %%
import time
num_epochs = 10000
start = time.time()
#for epoch
for epoch in range(num_epochs):

    #get random batch
    input, target, cooc, weightin = random_batch(batch_size, corpus_tokenized, skipgrams, counter, weighting_dic)
    input_batch    = torch.LongTensor(input)
    target_batch   = torch.LongTensor(target)
    cooc_batch     = torch.FloatTensor(cooc)
    weightin_batch = torch.FloatTensor(weightin)
    
    
    # print(input_batch.shape, label_batch.shape, cooc_batch.shape, weightin_batch)
    
    #loss = model
    loss = model(input_batch, target_batch, cooc_batch, weightin_batch)
    
    #backpropagate
    loss.backward()
    
    #update alpha
    optimizer.step()
    
    #print epoch loss
    if (epoch + 1) % 1000 == 0:
        end = time.time()
        print(f"Epoch {epoch+1} | Loss: {loss:.6f} | Time: {(end-start)}")
# Out:
# Epoch 1000 | Loss: 0.903848 | Time: 92.30448770523071
# Epoch 2000 | Loss: 2.258793 | Time: 184.53154754638672
# Epoch 3000 | Loss: 0.874341 | Time: 278.80912017822266
# Epoch 4000 | Loss: 5.138236 | Time: 388.8800718784332
# Epoch 5000 | Loss: 0.321889 | Time: 485.19514536857605
# Epoch 6000 | Loss: 0.038435 | Time: 583.4276509284973
# Epoch 7000 | Loss: 1.639333 | Time: 675.4691689014435
# Epoch 8000 | Loss: 1.544374 | Time: 773.6081693172455
# Epoch 9000 | Loss: 1.600980 | Time: 879.683146238327
# Epoch 10000 | Loss: 0.605473 | Time: 966.5016851425171

# %%
plt.figure(figsize=(6,3))
for i, word in enumerate(vocabs[:20]): #loop each unique vocab
    x, y = get_embed(word)
    plt.scatter(x, y)
    plt.annotate(word, xy=(x, y), xytext=(5, 2), textcoords='offset points')
plt.title('Cbow with window size of 2')
plt.show()

# %%
torch.save(model.state_dict(), "./model/GloveModel.pth")
with open('./model/GloveModel.pkl','wb') as f:
    pickle.dump(model,f)

# %%
import pickle
with open('./model/GloveModel.pkl','rb') as f:
    model_test = pickle.load(f)

# %%
def get_embed(word):
    index = word2index.get(word,0)
    word = torch.LongTensor([index])

    center_embed  = model.embedding_v(word)
    outside_embed = model.embedding_u(word)
    
    embed = (center_embed + outside_embed) / 2
    
    return  embed[0][0].item(), embed[0][1].item()

# %%
#let's try similarity between first and second, and second and third
usual = get_embed('usual')
usually = get_embed('usually')
serious = get_embed('serious')
print(f"usual vs. usually: ",cosine_similarity(usual, usually))
print(f"usually vs. serious: ",cosine_similarity(usually, serious))
# Out:
# usual vs. usually:  -0.2065037076413183
# usually vs. serious:  -0.03125707114334597

# %%
from scipy import spatial

def cosine_similarity(word1, word2):
    '''
        cosine_similarity function accepts the embeddings of two words and returns the 
        the degree of similarity between them using scipy.
    '''
    cos_sim = 1 - spatial.distance.cosine(word1, word2)  #distance = 1 - similarlity, because scipy only gives distance
    return cos_sim

# %%
import spacy 

nlp = spacy.load('en_core_web_sm')
text = open('./dataset/questions-words.txt',mode='r')
df = pd.DataFrame(text.readlines())
df.shape
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-2-9108c6b25825> in <module>
#       1 import spacy
#       2
# ----> 3 nlp = spacy.load('en_core_web_sm')
#       4 text = open('./dataset/questions-words.txt',mode='r')
#       5 df = pd.DataFrame(text.readlines())
#
# c:\users\sagar\appdata\local\programs\python\python38\lib\site-packages\spacy\__init__.py in load(name, vocab, disable, enable, exclude, config)
#      52     RETURNS (Language): The loaded nlp object.
#      53     """
# ---> 54     return util.load_model(
#      55         name,
#      56         vocab=vocab,
#
# c:\users\sagar\appdata\local\programs\python\python38\lib\site-packages\spacy\util.py in load_model(name, vocab, disable, enable, exclude, config)
#     437     if name in OLD_MODEL_SHORTCUTS:
#     438         raise IOError(Errors.E941.format(name=name, full=OLD_MODEL_SHORTCUTS[name]))  # type: ignore[index]
# --> 439     raise IOError(Errors.E050.format(name=name))
#     440
#     441
#
# OSError: [E050] Can't find model 'en_core_web_sm'. It doesn't seem to be a Python package or a valid path to a data directory.

# %%
# !python -m spacy download en_core_web_sm
# Out:
# 2023-01-26 20:29:27.752172: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'cudart64_101.dll'; dlerror: cudart64_101.dll not found
# 2023-01-26 20:29:27.752206: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-01-26 20:29:30.248165: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library nvcuda.dll
# 2023-01-26 20:29:30.264047: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: GeForce GTX 1650 computeCapability: 7.5
# coreClock: 1.56GHz coreCount: 16 deviceMemorySize: 4.00GiB deviceMemoryBandwidth: 119.24GiB/s
# 2023-01-26 20:29:30.264536: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'cudart64_101.dll'; dlerror: cudart64_101.dll not found
# 2023-01-26 20:29:30.264907: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'cublas64_10.dll'; dlerror: cublas64_10.dll not found
# 2023-01-26 20:29:30.265260: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'cufft64_10.dll'; dlerror: cufft64_10.dll not found
# 2023-01-26 20:29:30.265643: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'curand64_10.dll'; dlerror: curand64_10.dll not found
# 2023-01-26 20:29:30.265994: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'cusolver64_10.dll'; dlerror: cusolver64_10.dll not found
# 2023-01-26 20:29:30.266337: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'cusparse64_10.dll'; dlerror: cusparse64_10.dll not found
# 2023-01-26 20:29:30.266714: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'cudnn64_7.dll'; dlerror: cudnn64_7.dll not found
# 2023-01-26 20:29:30.266725: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1753] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# Traceback (most recent call last):
#   File "C:\Users\Sagar\AppData\Local\Programs\Python\Python38\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\Sagar\AppData\Local\Programs\Python\Python38\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\Sagar\AppData\Local\Programs\Python\Python38\lib\site-packages\spacy\__main__.py", line 4, in <module>
#     setup_cli()
#   File "C:\Users\Sagar\AppData\Local\Programs\Python\Python38\lib\site-packages\spacy\cli\_util.py", line 74, in setup_cli
#     command(prog_name=COMMAND)
#   File "C:\Users\Sagar\AppData\Local\Programs\Python\Python38\lib\site-packages\click\core.py", line 829, in __call__
#     return self.main(*args, **kwargs)
#   File "C:\Users\Sagar\AppData\Local\Programs\Python\Python38\lib\site-packages\typer\core.py", line 778, in main
#     return _main(
#   File "C:\Users\Sagar\AppData\Local\Programs\Python\Python38\lib\site-packages\typer\core.py", line 190, in _main
#     args = click.utils._expand_args(args)
# AttributeError: module 'click.utils' has no attribute '_expand_args'

# %%
header = df[0].str.startswith(':')
index_list = np.where(header)[0].tolist()
print(index_list)

# %%
df1 = df[8875:9867]
df2 = df[9868:10680]
df3 = df[10681:12013]

# %%
def find_analogy(a,b,c,vocabs=vocabs):
    emb_a, emb_b, emb_c = get_embed_test(a),get_embed_test(b),get_embed_test(c)
    vector = emb_b - emb_a + emb_c
    # vector_norm = (vector ** 2).sum() ** (1 / 2)
    # vector = vector / vector_norm
    # print(vector.shape)
    similarity = -1 
    
    for vocab in vocabs:
        if vocab not in [a,b,c]: #ignore input words itself
            current_sim = cos_sim(vector,get_embed_test(vocab))
            if current_sim > similarity:
                similarity = current_sim #update better one
                d = (vocab, similarity)
    return d
